# %% [markdown]
# <a href="https://colab.research.google.com/github/cabbi120101/TIL/blob/master/%EA%B3%B5%EB%AA%A8%EC%A0%84%EA%B3%B5%EB%B6%80/%EC%BD%94%EB%A1%9C%EB%82%98(%EC%8B%9C_%EB%8F%84).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 ! pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.12.0

# %%
from urllib.request import urlopen, Request
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

# %%
key = ''

num_of_rows = 10 # 한페이지에 포함된 결과 수 
page_no = 1 #페이지 번호
url = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson'
start_Date = 20200201
end_Date = 20210705

req_parameter = '?' + urlencode({
    'serviceKey':  key,
    'numOfRows' : num_of_rows,
    'pageNo' : page_no,
    'startCreate_dt' : start_Date,
    'endCreateDt' : end_Date,
})

r = requests.get(url + req_parameter)
response_content = json.loads(json.dumps(xmltodict.parse(r.text)))
response_content['response']['body']['items']['item']
# Out:
# [{'createDt': '2021-07-05 09:54:03.148',
#   'deathCnt': '5',
#   'defCnt': '4378',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '25',
#   'isolClearCnt': '4015',
#   'isolIngCnt': '358',
#   'localOccCnt': '0',
#   'overFlowCnt': '25',
#   'qurRate': '-',
#   'seq': '10533',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.148',
#   'deathCnt': '1',
#   'defCnt': '1280',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '6',
#   'isolClearCnt': '1238',
#   'isolIngCnt': '41',
#   'localOccCnt': '5',
#   'overFlowCnt': '1',
#   'qurRate': '190.83',
#   'seq': '10532',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.148',
#   'deathCnt': '21',
#   'defCnt': '5317',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '22',
#   'isolClearCnt': '5141',
#   'isolIngCnt': '155',
#   'localOccCnt': '20',
#   'overFlowCnt': '2',
#   'qurRate': '158.18',
#   'seq': '10531',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.148',
#   'deathCnt': '86',
#   'defCnt': '4987',
#   'gubun': '경북',
#   'gubunCn': '庆北',
#   'gubunEn': 'Gyeongsangbuk-do',
#   'incDec': '13',
#   'isolClearCnt': '4810',
#   'isolIngCnt': '91',
#   'localOccCnt': '10',
#   'overFlowCnt': '3',
#   'qurRate': '187.30',
#   'seq': '10530',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.148',
#   'deathCnt': '16',
#   'defCnt': '1670',
#   'gubun': '전남',
#   'gubunCn': '全南',
#   'gubunEn': 'Jeollanam-do',
#   'incDec': '6',
#   'isolClearCnt': '1559',
#   'isolIngCnt': '95',
#   'localOccCnt': '3',
#   'overFlowCnt': '3',
#   'qurRate': '89.56',
#   'seq': '10529',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.147',
#   'deathCnt': '59',
#   'defCnt': '2391',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '6',
#   'isolClearCnt': '2265',
#   'isolIngCnt': '67',
#   'localOccCnt': '6',
#   'overFlowCnt': '0',
#   'qurRate': '131.57',
#   'seq': '10528',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.147',
#   'deathCnt': '43',
#   'defCnt': '3881',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '12',
#   'isolClearCnt': '3677',
#   'isolIngCnt': '161',
#   'localOccCnt': '10',
#   'overFlowCnt': '2',
#   'qurRate': '182.85',
#   'seq': '10527',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.147',
#   'deathCnt': '71',
#   'defCnt': '3328',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '3',
#   'isolClearCnt': '3189',
#   'isolIngCnt': '68',
#   'localOccCnt': '3',
#   'overFlowCnt': '0',
#   'qurRate': '208.08',
#   'seq': '10526',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.147',
#   'deathCnt': '53',
#   'defCnt': '3620',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '7',
#   'isolClearCnt': '3400',
#   'isolIngCnt': '167',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '234.98',
#   'seq': '10525',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.147',
#   'deathCnt': '656',
#   'defCnt': '45275',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '220',
#   'isolClearCnt': '41889',
#   'isolIngCnt': '2730',
#   'localOccCnt': '210',
#   'overFlowCnt': '10',
#   'qurRate': '341.69',
#   'seq': '10524',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.147',
#   'deathCnt': '1',
#   'defCnt': '578',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '4',
#   'isolClearCnt': '541',
#   'isolIngCnt': '36',
#   'localOccCnt': '4',
#   'overFlowCnt': '0',
#   'qurRate': '168.84',
#   'seq': '10523',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.147',
#   'deathCnt': '40',
#   'defCnt': '2852',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '1',
#   'isolClearCnt': '2738',
#   'isolIngCnt': '74',
#   'localOccCnt': '1',
#   'overFlowCnt': '0',
#   'qurRate': '248.64',
#   'seq': '10522',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.146',
#   'deathCnt': '27',
#   'defCnt': '2771',
#   'gubun': '대전',
#   'gubunCn': '大田',
#   'gubunEn': 'Daejeon',
#   'incDec': '19',
#   'isolClearCnt': '2489',
#   'isolIngCnt': '255',
#   'localOccCnt': '18',
#   'overFlowCnt': '1',
#   'qurRate': '187.97',
#   'seq': '10521',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.146',
#   'deathCnt': '24',
#   'defCnt': '2959',
#   'gubun': '광주',
#   'gubunCn': '光州',
#   'gubunEn': 'Gwangju',
#   'incDec': '7',
#   'isolClearCnt': '2873',
#   'isolIngCnt': '62',
#   'localOccCnt': '6',
#   'overFlowCnt': '1',
#   'qurRate': '203.13',
#   'seq': '10520',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.146',
#   'deathCnt': '61',
#   'defCnt': '6896',
#   'gubun': '인천',
#   'gubunCn': '仁川',
#   'gubunEn': 'Incheon',
#   'incDec': '22',
#   'isolClearCnt': '6551',
#   'isolIngCnt': '284',
#   'localOccCnt': '16',
#   'overFlowCnt': '6',
#   'qurRate': '233.28',
#   'seq': '10519',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.146',
#   'deathCnt': '222',
#   'defCnt': '10631',
#   'gubun': '대구',
#   'gubunCn': '大邱',
#   'gubunEn': 'Daegu',
#   'incDec': '6',
#   'isolClearCnt': '10325',
#   'isolIngCnt': '84',
#   'localOccCnt': '4',
#   'overFlowCnt': '2',
#   'qurRate': '436.32',
#   'seq': '10518',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.146',
#   'deathCnt': '125',
#   'defCnt': '6360',
#   'gubun': '부산',
#   'gubunCn': '釜山',
#   'gubunEn': 'Busan',
#   'incDec': '25',
#   'isolClearCnt': '5947',
#   'isolIngCnt': '288',
#   'localOccCnt': '20',
#   'overFlowCnt': '5',
#   'qurRate': '186.41',
#   'seq': '10517',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.145',
#   'deathCnt': '517',
#   'defCnt': '51621',
#   'gubun': '서울',
#   'gubunCn': '首尔',
#   'gubunEn': 'Seoul',
#   'incDec': '307',
#   'isolClearCnt': '47397',
#   'isolIngCnt': '3707',
#   'localOccCnt': '301',
#   'overFlowCnt': '6',
#   'qurRate': '530.34',
#   'seq': '10516',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-05 09:54:03.145',
#   'deathCnt': '2028',
#   'defCnt': '160795',
#   'gubun': '합계',
#   'gubunCn': '合计',
#   'gubunEn': 'Total',
#   'incDec': '711',
#   'isolClearCnt': '150044',
#   'isolIngCnt': '8723',
#   'localOccCnt': '644',
#   'overFlowCnt': '67',
#   'qurRate': '310.13',
#   'seq': '10515',
#   'stdDay': '2021년 07월 05일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.58',
#   'deathCnt': '5',
#   'defCnt': '4353',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '50',
#   'isolClearCnt': '4015',
#   'isolIngCnt': '333',
#   'localOccCnt': '0',
#   'overFlowCnt': '50',
#   'qurRate': '-',
#   'seq': '10514',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.58',
#   'deathCnt': '1',
#   'defCnt': '1274',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '2',
#   'isolClearCnt': '1236',
#   'isolIngCnt': '37',
#   'localOccCnt': '2',
#   'overFlowCnt': '0',
#   'qurRate': '189.94',
#   'seq': '10513',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.58',
#   'deathCnt': '21',
#   'defCnt': '5295',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '15',
#   'isolClearCnt': '5119',
#   'isolIngCnt': '155',
#   'localOccCnt': '14',
#   'overFlowCnt': '1',
#   'qurRate': '157.53',
#   'seq': '10512',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.58',
#   'deathCnt': '86',
#   'defCnt': '4974',
#   'gubun': '경북',
#   'gubunCn': '庆北',
#   'gubunEn': 'Gyeongsangbuk-do',
#   'incDec': '9',
#   'isolClearCnt': '4797',
#   'isolIngCnt': '91',
#   'localOccCnt': '8',
#   'overFlowCnt': '1',
#   'qurRate': '186.82',
#   'seq': '10511',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.58',
#   'deathCnt': '16',
#   'defCnt': '1664',
#   'gubun': '전남',
#   'gubunCn': '全南',
#   'gubunEn': 'Jeollanam-do',
#   'incDec': '0',
#   'isolClearCnt': '1556',
#   'isolIngCnt': '92',
#   'localOccCnt': '0',
#   'overFlowCnt': '0',
#   'qurRate': '89.24',
#   'seq': '10510',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.579',
#   'deathCnt': '59',
#   'defCnt': '2385',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '3',
#   'isolClearCnt': '2261',
#   'isolIngCnt': '65',
#   'localOccCnt': '2',
#   'overFlowCnt': '1',
#   'qurRate': '131.24',
#   'seq': '10509',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.579',
#   'deathCnt': '43',
#   'defCnt': '3869',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '7',
#   'isolClearCnt': '3674',
#   'isolIngCnt': '152',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '182.29',
#   'seq': '10508',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.579',
#   'deathCnt': '71',
#   'defCnt': '3325',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '2',
#   'isolClearCnt': '3188',
#   'isolIngCnt': '66',
#   'localOccCnt': '2',
#   'overFlowCnt': '0',
#   'qurRate': '207.89',
#   'seq': '10507',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.579',
#   'deathCnt': '53',
#   'defCnt': '3613',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '19',
#   'isolClearCnt': '3384',
#   'isolIngCnt': '176',
#   'localOccCnt': '11',
#   'overFlowCnt': '8',
#   'qurRate': '234.53',
#   'seq': '10506',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.579',
#   'deathCnt': '655',
#   'defCnt': '45055',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '231',
#   'isolClearCnt': '41785',
#   'isolIngCnt': '2615',
#   'localOccCnt': '227',
#   'overFlowCnt': '4',
#   'qurRate': '340.03',
#   'seq': '10505',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.579',
#   'deathCnt': '1',
#   'defCnt': '574',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '4',
#   'isolClearCnt': '537',
#   'isolIngCnt': '36',
#   'localOccCnt': '4',
#   'overFlowCnt': '0',
#   'qurRate': '167.68',
#   'seq': '10504',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.578',
#   'deathCnt': '40',
#   'defCnt': '2851',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '13',
#   'isolClearCnt': '2727',
#   'isolIngCnt': '84',
#   'localOccCnt': '10',
#   'overFlowCnt': '3',
#   'qurRate': '248.55',
#   'seq': '10503',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.578',
#   'deathCnt': '27',
#   'defCnt': '2752',
#   'gubun': '대전',
#   'gubunCn': '大田',
#   'gubunEn': 'Daejeon',
#   'incDec': '32',
#   'isolClearCnt': '2477',
#   'isolIngCnt': '248',
#   'localOccCnt': '32',
#   'overFlowCnt': '0',
#   'qurRate': '186.68',
#   'seq': '10502',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.578',
#   'deathCnt': '24',
#   'defCnt': '2952',
#   'gubun': '광주',
#   'gubunCn': '光州',
#   'gubunEn': 'Gwangju',
#   'incDec': '3',
#   'isolClearCnt': '2872',
#   'isolIngCnt': '56',
#   'localOccCnt': '1',
#   'overFlowCnt': '2',
#   'qurRate': '202.65',
#   'seq': '10501',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.578',
#   'deathCnt': '61',
#   'defCnt': '6874',
#   'gubun': '인천',
#   'gubunCn': '仁川',
#   'gubunEn': 'Incheon',
#   'incDec': '33',
#   'isolClearCnt': '6537',
#   'isolIngCnt': '276',
#   'localOccCnt': '28',
#   'overFlowCnt': '5',
#   'qurRate': '232.53',
#   'seq': '10500',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.577',
#   'deathCnt': '222',
#   'defCnt': '10625',
#   'gubun': '대구',
#   'gubunCn': '大邱',
#   'gubunEn': 'Daegu',
#   'incDec': '3',
#   'isolClearCnt': '10321',
#   'isolIngCnt': '82',
#   'localOccCnt': '2',
#   'overFlowCnt': '1',
#   'qurRate': '436.08',
#   'seq': '10499',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.577',
#   'deathCnt': '125',
#   'defCnt': '6335',
#   'gubun': '부산',
#   'gubunCn': '釜山',
#   'gubunEn': 'Busan',
#   'incDec': '28',
#   'isolClearCnt': '5921',
#   'isolIngCnt': '289',
#   'localOccCnt': '26',
#   'overFlowCnt': '2',
#   'qurRate': '185.68',
#   'seq': '10498',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.577',
#   'deathCnt': '516',
#   'defCnt': '51314',
#   'gubun': '서울',
#   'gubunCn': '首尔',
#   'gubunEn': 'Seoul',
#   'incDec': '289',
#   'isolClearCnt': '47207',
#   'isolIngCnt': '3591',
#   'localOccCnt': '286',
#   'overFlowCnt': '3',
#   'qurRate': '527.19',
#   'seq': '10497',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-04 09:40:05.577',
#   'deathCnt': '2026',
#   'defCnt': '160084',
#   'gubun': '합계',
#   'gubunCn': '合计',
#   'gubunEn': 'Total',
#   'incDec': '743',
#   'isolClearCnt': '149614',
#   'isolIngCnt': '8444',
#   'localOccCnt': '662',
#   'overFlowCnt': '81',
#   'qurRate': '308.76',
#   'seq': '10496',
#   'stdDay': '2021년 07월 04일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.439',
#   'deathCnt': '5',
#   'defCnt': '4303',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '23',
#   'isolClearCnt': '3998',
#   'isolIngCnt': '300',
#   'localOccCnt': '0',
#   'overFlowCnt': '23',
#   'qurRate': '-',
#   'seq': '10495',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.439',
#   'deathCnt': '1',
#   'defCnt': '1272',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '4',
#   'isolClearCnt': '1234',
#   'isolIngCnt': '37',
#   'localOccCnt': '4',
#   'overFlowCnt': '0',
#   'qurRate': '189.64',
#   'seq': '10494',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.439',
#   'deathCnt': '21',
#   'defCnt': '5280',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '10',
#   'isolClearCnt': '5109',
#   'isolIngCnt': '150',
#   'localOccCnt': '8',
#   'overFlowCnt': '2',
#   'qurRate': '157.08',
#   'seq': '10493',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.439',
#   'deathCnt': '86',
#   'defCnt': '4965',
#   'gubun': '경북',
#   'gubunCn': '庆北',
#   'gubunEn': 'Gyeongsangbuk-do',
#   'incDec': '4',
#   'isolClearCnt': '4776',
#   'isolIngCnt': '103',
#   'localOccCnt': '3',
#   'overFlowCnt': '1',
#   'qurRate': '186.48',
#   'seq': '10492',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.438',
#   'deathCnt': '16',
#   'defCnt': '1664',
#   'gubun': '전남',
#   'gubunCn': '全南',
#   'gubunEn': 'Jeollanam-do',
#   'incDec': '7',
#   'isolClearCnt': '1552',
#   'isolIngCnt': '96',
#   'localOccCnt': '6',
#   'overFlowCnt': '1',
#   'qurRate': '89.24',
#   'seq': '10491',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.438',
#   'deathCnt': '59',
#   'defCnt': '2382',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '4',
#   'isolClearCnt': '2258',
#   'isolIngCnt': '65',
#   'localOccCnt': '4',
#   'overFlowCnt': '0',
#   'qurRate': '131.07',
#   'seq': '10490',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.438',
#   'deathCnt': '43',
#   'defCnt': '3862',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '16',
#   'isolClearCnt': '3667',
#   'isolIngCnt': '152',
#   'localOccCnt': '16',
#   'overFlowCnt': '0',
#   'qurRate': '181.96',
#   'seq': '10489',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.438',
#   'deathCnt': '71',
#   'defCnt': '3323',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '6',
#   'isolClearCnt': '3175',
#   'isolIngCnt': '77',
#   'localOccCnt': '5',
#   'overFlowCnt': '1',
#   'qurRate': '207.77',
#   'seq': '10488',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.438',
#   'deathCnt': '53',
#   'defCnt': '3594',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '11',
#   'isolClearCnt': '3379',
#   'isolIngCnt': '162',
#   'localOccCnt': '11',
#   'overFlowCnt': '0',
#   'qurRate': '233.29',
#   'seq': '10487',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.438',
#   'deathCnt': '654',
#   'defCnt': '44824',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '252',
#   'isolClearCnt': '41629',
#   'isolIngCnt': '2541',
#   'localOccCnt': '247',
#   'overFlowCnt': '5',
#   'qurRate': '338.28',
#   'seq': '10486',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.437',
#   'deathCnt': '1',
#   'defCnt': '570',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '3',
#   'isolClearCnt': '536',
#   'isolIngCnt': '33',
#   'localOccCnt': '3',
#   'overFlowCnt': '0',
#   'qurRate': '166.51',
#   'seq': '10485',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.437',
#   'deathCnt': '40',
#   'defCnt': '2838',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '1',
#   'isolClearCnt': '2707',
#   'isolIngCnt': '91',
#   'localOccCnt': '0',
#   'overFlowCnt': '1',
#   'qurRate': '247.42',
#   'seq': '10484',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.437',
#   'deathCnt': '27',
#   'defCnt': '2720',
#   'gubun': '대전',
#   'gubunCn': '大田',
#   'gubunEn': 'Daejeon',
#   'incDec': '28',
#   'isolClearCnt': '2463',
#   'isolIngCnt': '230',
#   'localOccCnt': '28',
#   'overFlowCnt': '0',
#   'qurRate': '184.51',
#   'seq': '10483',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.437',
#   'deathCnt': '24',
#   'defCnt': '2949',
#   'gubun': '광주',
#   'gubunCn': '光州',
#   'gubunEn': 'Gwangju',
#   'incDec': '3',
#   'isolClearCnt': '2868',
#   'isolIngCnt': '57',
#   'localOccCnt': '3',
#   'overFlowCnt': '0',
#   'qurRate': '202.45',
#   'seq': '10482',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.437',
#   'deathCnt': '61',
#   'defCnt': '6841',
#   'gubun': '인천',
#   'gubunCn': '仁川',
#   'gubunEn': 'Incheon',
#   'incDec': '16',
#   'isolClearCnt': '6522',
#   'isolIngCnt': '258',
#   'localOccCnt': '14',
#   'overFlowCnt': '2',
#   'qurRate': '231.42',
#   'seq': '10481',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.437',
#   'deathCnt': '222',
#   'defCnt': '10622',
#   'gubun': '대구',
#   'gubunCn': '大邱',
#   'gubunEn': 'Daegu',
#   'incDec': '8',
#   'isolClearCnt': '10317',
#   'isolIngCnt': '83',
#   'localOccCnt': '8',
#   'overFlowCnt': '0',
#   'qurRate': '435.96',
#   'seq': '10480',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.436',
#   'deathCnt': '125',
#   'defCnt': '6307',
#   'gubun': '부산',
#   'gubunCn': '釜山',
#   'gubunEn': 'Busan',
#   'incDec': '39',
#   'isolClearCnt': '5894',
#   'isolIngCnt': '288',
#   'localOccCnt': '35',
#   'overFlowCnt': '4',
#   'qurRate': '184.86',
#   'seq': '10479',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.436',
#   'deathCnt': '516',
#   'defCnt': '51026',
#   'gubun': '서울',
#   'gubunCn': '首尔',
#   'gubunEn': 'Seoul',
#   'incDec': '359',
#   'isolClearCnt': '47048',
#   'isolIngCnt': '3462',
#   'localOccCnt': '353',
#   'overFlowCnt': '6',
#   'qurRate': '524.23',
#   'seq': '10478',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-03 10:05:49.436',
#   'deathCnt': '2025',
#   'defCnt': '159342',
#   'gubun': '합계',
#   'gubunCn': '合计',
#   'gubunEn': 'Total',
#   'incDec': '794',
#   'isolClearCnt': '149132',
#   'isolIngCnt': '8185',
#   'localOccCnt': '748',
#   'overFlowCnt': '46',
#   'qurRate': '307.33',
#   'seq': '10477',
#   'stdDay': '2021년 07월 03일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.691',
#   'deathCnt': '5',
#   'defCnt': '4280',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '33',
#   'isolClearCnt': '3986',
#   'isolIngCnt': '289',
#   'localOccCnt': '0',
#   'overFlowCnt': '33',
#   'qurRate': '-',
#   'seq': '10476',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.691',
#   'deathCnt': '1',
#   'defCnt': '1268',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '3',
#   'isolClearCnt': '1229',
#   'isolIngCnt': '38',
#   'localOccCnt': '3',
#   'overFlowCnt': '0',
#   'qurRate': '189.04',
#   'seq': '10475',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.691',
#   'deathCnt': '21',
#   'defCnt': '5270',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '13',
#   'isolClearCnt': '5081',
#   'isolIngCnt': '168',
#   'localOccCnt': '12',
#   'overFlowCnt': '1',
#   'qurRate': '156.78',
#   'seq': '10474',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.691',
#   'deathCnt': '86',
#   'defCnt': '4961',
#   'gubun': '경북',
#   'gubunCn': '庆北',
#   'gubunEn': 'Gyeongsangbuk-do',
#   'incDec': '7',
#   'isolClearCnt': '4760',
#   'isolIngCnt': '115',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '186.33',
#   'seq': '10473',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.69',
#   'deathCnt': '16',
#   'defCnt': '1657',
#   'gubun': '전남',
#   'gubunCn': '全南',
#   'gubunEn': 'Jeollanam-do',
#   'incDec': '4',
#   'isolClearCnt': '1544',
#   'isolIngCnt': '97',
#   'localOccCnt': '4',
#   'overFlowCnt': '0',
#   'qurRate': '88.86',
#   'seq': '10472',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.69',
#   'deathCnt': '59',
#   'defCnt': '2378',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '7',
#   'isolClearCnt': '2255',
#   'isolIngCnt': '64',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '130.85',
#   'seq': '10471',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.69',
#   'deathCnt': '43',
#   'defCnt': '3846',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '27',
#   'isolClearCnt': '3657',
#   'isolIngCnt': '146',
#   'localOccCnt': '27',
#   'overFlowCnt': '0',
#   'qurRate': '181.21',
#   'seq': '10470',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.69',
#   'deathCnt': '71',
#   'defCnt': '3317',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '7',
#   'isolClearCnt': '3155',
#   'isolIngCnt': '91',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '207.39',
#   'seq': '10469',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.69',
#   'deathCnt': '53',
#   'defCnt': '3583',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '14',
#   'isolClearCnt': '3361',
#   'isolIngCnt': '169',
#   'localOccCnt': '7',
#   'overFlowCnt': '7',
#   'qurRate': '232.58',
#   'seq': '10468',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.689',
#   'deathCnt': '654',
#   'defCnt': '44572',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '264',
#   'isolClearCnt': '41410',
#   'isolIngCnt': '2508',
#   'localOccCnt': '260',
#   'overFlowCnt': '4',
#   'qurRate': '336.38',
#   'seq': '10467',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.689',
#   'deathCnt': '1',
#   'defCnt': '567',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '2',
#   'isolClearCnt': '529',
#   'isolIngCnt': '37',
#   'localOccCnt': '2',
#   'overFlowCnt': '0',
#   'qurRate': '165.63',
#   'seq': '10466',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.689',
#   'deathCnt': '40',
#   'defCnt': '2837',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '11',
#   'isolClearCnt': '2700',
#   'isolIngCnt': '97',
#   'localOccCnt': '10',
#   'overFlowCnt': '1',
#   'qurRate': '247.33',
#   'seq': '10465',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.689',
#   'deathCnt': '27',
#   'defCnt': '2692',
#   'gubun': '대전',
#   'gubunCn': '大田',
#   'gubunEn': 'Daejeon',
#   'incDec': '25',
#   'isolClearCnt': '2428',
#   'isolIngCnt': '237',
#   'localOccCnt': '25',
#   'overFlowCnt': '0',
#   'qurRate': '182.61',
#   'seq': '10464',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.689',
#   'deathCnt': '24',
#   'defCnt': '2946',
#   'gubun': '광주',
#   'gubunCn': '光州',
#   'gubunEn': 'Gwangju',
#   'incDec': '2',
#   'isolClearCnt': '2864',
#   'isolIngCnt': '58',
#   'localOccCnt': '2',
#   'overFlowCnt': '0',
#   'qurRate': '202.24',
#   'seq': '10463',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.688',
#   'deathCnt': '61',
#   'defCnt': '6825',
#   'gubun': '인천',
#   'gubunCn': '仁川',
#   'gubunEn': 'Incheon',
#   'incDec': '22',
#   'isolClearCnt': '6502',
#   'isolIngCnt': '262',
#   'localOccCnt': '22',
#   'overFlowCnt': '0',
#   'qurRate': '230.88',
#   'seq': '10462',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.688',
#   'deathCnt': '222',
#   'defCnt': '10614',
#   'gubun': '대구',
#   'gubunCn': '大邱',
#   'gubunEn': 'Daegu',
#   'incDec': '9',
#   'isolClearCnt': '10310',
#   'isolIngCnt': '82',
#   'localOccCnt': '8',
#   'overFlowCnt': '1',
#   'qurRate': '435.63',
#   'seq': '10461',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.688',
#   'deathCnt': '125',
#   'defCnt': '6268',
#   'gubun': '부산',
#   'gubunCn': '釜山',
#   'gubunEn': 'Busan',
#   'incDec': '29',
#   'isolClearCnt': '5880',
#   'isolIngCnt': '263',
#   'localOccCnt': '25',
#   'overFlowCnt': '4',
#   'qurRate': '183.71',
#   'seq': '10460',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-02 09:48:52.688',
#   'deathCnt': '515',
#   'defCnt': '50667',
#   'gubun': '서울',
#   'gubunCn': '首尔',
#   'gubunEn': 'Seoul',
#   'incDec': '347',
#   'isolClearCnt': '46668',
#   'isolIngCnt': '3484',
#   'localOccCnt': '337',
#   'overFlowCnt': '10',
#   'qurRate': '520.55',
#   'seq': '10459',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': '2021-07-03 09:54:59.186'},
#  {'createDt': '2021-07-02 09:48:52.688',
#   'deathCnt': '2024',
#   'defCnt': '158548',
#   'gubun': '합계',
#   'gubunCn': '合计',
#   'gubunEn': 'Total',
#   'incDec': '826',
#   'isolClearCnt': '148319',
#   'isolIngCnt': '8205',
#   'localOccCnt': '765',
#   'overFlowCnt': '61',
#   'qurRate': '305.80',
#   'seq': '10458',
#   'stdDay': '2021년 07월 02일 00시',
#   'updateDt': '2021-07-03 09:53:15.85'},
#  {'createDt': '2021-07-01 09:42:20.54',
#   'deathCnt': '5',
#   'defCnt': '4247',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '31',
#   'isolClearCnt': '3982',
#   'isolIngCnt': '260',
#   'localOccCnt': '0',
#   'overFlowCnt': '31',
#   'qurRate': '-',
#   'seq': '10457',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.54',
#   'deathCnt': '1',
#   'defCnt': '1265',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '1',
#   'isolClearCnt': '1228',
#   'isolIngCnt': '36',
#   'localOccCnt': '1',
#   'overFlowCnt': '0',
#   'qurRate': '188.60',
#   'seq': '10456',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.539',
#   'deathCnt': '20',
#   'defCnt': '5257',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '10',
#   'isolClearCnt': '5072',
#   'isolIngCnt': '165',
#   'localOccCnt': '10',
#   'overFlowCnt': '0',
#   'qurRate': '156.40',
#   'seq': '10455',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.539',
#   'deathCnt': '86',
#   'defCnt': '4954',
#   'gubun': '경북',
#   'gubunCn': '庆北',
#   'gubunEn': 'Gyeongsangbuk-do',
#   'incDec': '5',
#   'isolClearCnt': '4757',
#   'isolIngCnt': '111',
#   'localOccCnt': '4',
#   'overFlowCnt': '1',
#   'qurRate': '186.07',
#   'seq': '10454',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.539',
#   'deathCnt': '16',
#   'defCnt': '1653',
#   'gubun': '전남',
#   'gubunCn': '全南',
#   'gubunEn': 'Jeollanam-do',
#   'incDec': '5',
#   'isolClearCnt': '1542',
#   'isolIngCnt': '95',
#   'localOccCnt': '5',
#   'overFlowCnt': '0',
#   'qurRate': '88.65',
#   'seq': '10453',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.539',
#   'deathCnt': '59',
#   'defCnt': '2371',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '7',
#   'isolClearCnt': '2252',
#   'isolIngCnt': '60',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '130.47',
#   'seq': '10452',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.539',
#   'deathCnt': '43',
#   'defCnt': '3819',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '15',
#   'isolClearCnt': '3648',
#   'isolIngCnt': '128',
#   'localOccCnt': '13',
#   'overFlowCnt': '2',
#   'qurRate': '179.93',
#   'seq': '10451',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.539',
#   'deathCnt': '70',
#   'defCnt': '3310',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '4',
#   'isolClearCnt': '3150',
#   'isolIngCnt': '90',
#   'localOccCnt': '4',
#   'overFlowCnt': '0',
#   'qurRate': '206.95',
#   'seq': '10450',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.539',
#   'deathCnt': '53',
#   'defCnt': '3569',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '10',
#   'isolClearCnt': '3345',
#   'isolIngCnt': '171',
#   'localOccCnt': '8',
#   'overFlowCnt': '2',
#   'qurRate': '231.67',
#   'seq': '10449',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.538',
#   'deathCnt': '654',
#   'defCnt': '44308',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '249',
#   'isolClearCnt': '41313',
#   'isolIngCnt': '2341',
#   'localOccCnt': '245',
#   'overFlowCnt': '4',
#   'qurRate': '334.39',
#   'seq': '10448',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.538',
#   'deathCnt': '1',
#   'defCnt': '565',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '5',
#   'isolClearCnt': '524',
#   'isolIngCnt': '40',
#   'localOccCnt': '5',
#   'overFlowCnt': '0',
#   'qurRate': '165.05',
#   'seq': '10447',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.538',
#   'deathCnt': '40',
#   'defCnt': '2826',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '2',
#   'isolClearCnt': '2694',
#   'isolIngCnt': '92',
#   'localOccCnt': '1',
#   'overFlowCnt': '1',
#   'qurRate': '246.37',
#   'seq': '10446',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.538',
#   'deathCnt': '27',
#   'defCnt': '2667',
#   'gubun': '대전',
#   'gubunCn': '大田',
#   'gubunEn': 'Daejeon',
#   'incDec': '16',
#   'isolClearCnt': '2406',
#   'isolIngCnt': '234',
#   'localOccCnt': '16',
#   'overFlowCnt': '0',
#   'qurRate': '180.92',
#   'seq': '10445',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.538',
#   'deathCnt': '24',
#   'defCnt': '2944',
#   'gubun': '광주',
#   'gubunCn': '光州',
#   'gubunEn': 'Gwangju',
#   'incDec': '7',
#   'isolClearCnt': '2862',
#   'isolIngCnt': '58',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '202.10',
#   'seq': '10444',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.538',
#   'deathCnt': '61',
#   'defCnt': '6803',
#   'gubun': '인천',
#   'gubunCn': '仁川',
#   'gubunEn': 'Incheon',
#   'incDec': '36',
#   'isolClearCnt': '6479',
#   'isolIngCnt': '263',
#   'localOccCnt': '30',
#   'overFlowCnt': '6',
#   'qurRate': '230.13',
#   'seq': '10443',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.538',
#   'deathCnt': '222',
#   'defCnt': '10605',
#   'gubun': '대구',
#   'gubunCn': '大邱',
#   'gubunEn': 'Daegu',
#   'incDec': '7',
#   'isolClearCnt': '10307',
#   'isolIngCnt': '76',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '435.26',
#   'seq': '10442',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.537',
#   'deathCnt': '125',
#   'defCnt': '6239',
#   'gubun': '부산',
#   'gubunCn': '釜山',
#   'gubunEn': 'Busan',
#   'incDec': '18',
#   'isolClearCnt': '5870',
#   'isolIngCnt': '244',
#   'localOccCnt': '17',
#   'overFlowCnt': '1',
#   'qurRate': '182.86',
#   'seq': '10441',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-07-01 09:42:20.537',
#   'deathCnt': '514',
#   'defCnt': '50321',
#   'gubun': '서울',
#   'gubunCn': '首尔',
#   'gubunEn': 'Seoul',
#   'incDec': '333',
#   'isolClearCnt': '46593',
#   'isolIngCnt': '3213',
#   'localOccCnt': '331',
#   'overFlowCnt': '2',
#   'qurRate': '516.99',
#   'seq': '10440',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': '2021-07-03 09:50:24.034'},
#  {'createDt': '2021-07-01 09:42:20.537',
#   'deathCnt': '2021',
#   'defCnt': '157723',
#   'gubun': '합계',
#   'gubunCn': '合计',
#   'gubunEn': 'Total',
#   'incDec': '761',
#   'isolClearCnt': '148024',
#   'isolIngCnt': '7677',
#   'localOccCnt': '711',
#   'overFlowCnt': '50',
#   'qurRate': '304.21',
#   'seq': '10439',
#   'stdDay': '2021년 07월 01일 00시',
#   'updateDt': '2021-07-03 09:49:52.238'},
#  {'createDt': '2021-06-30 09:43:12.326',
#   'deathCnt': '5',
#   'defCnt': '4216',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '17',
#   'isolClearCnt': '3973',
#   'isolIngCnt': '238',
#   'localOccCnt': '0',
#   'overFlowCnt': '17',
#   'qurRate': '-',
#   'seq': '10438',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.326',
#   'deathCnt': '1',
#   'defCnt': '1264',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '2',
#   'isolClearCnt': '1223',
#   'isolIngCnt': '40',
#   'localOccCnt': '2',
#   'overFlowCnt': '0',
#   'qurRate': '188.45',
#   'seq': '10437',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.326',
#   'deathCnt': '20',
#   'defCnt': '5247',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '17',
#   'isolClearCnt': '5061',
#   'isolIngCnt': '166',
#   'localOccCnt': '16',
#   'overFlowCnt': '1',
#   'qurRate': '156.10',
#   'seq': '10436',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.326',
#   'deathCnt': '86',
#   'defCnt': '4949',
#   'gubun': '경북',
#   'gubunCn': '庆北',
#   'gubunEn': 'Gyeongsangbuk-do',
#   'incDec': '4',
#   'isolClearCnt': '4750',
#   'isolIngCnt': '113',
#   'localOccCnt': '3',
#   'overFlowCnt': '1',
#   'qurRate': '185.88',
#   'seq': '10435',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.325',
#   'deathCnt': '15',
#   'defCnt': '1648',
#   'gubun': '전남',
#   'gubunCn': '全南',
#   'gubunEn': 'Jeollanam-do',
#   'incDec': '7',
#   'isolClearCnt': '1537',
#   'isolIngCnt': '96',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '88.38',
#   'seq': '10434',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.325',
#   'deathCnt': '59',
#   'defCnt': '2364',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '10',
#   'isolClearCnt': '2249',
#   'isolIngCnt': '56',
#   'localOccCnt': '10',
#   'overFlowCnt': '0',
#   'qurRate': '130.08',
#   'seq': '10433',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.325',
#   'deathCnt': '43',
#   'defCnt': '3804',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '8',
#   'isolClearCnt': '3633',
#   'isolIngCnt': '128',
#   'localOccCnt': '8',
#   'overFlowCnt': '0',
#   'qurRate': '179.23',
#   'seq': '10432',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.325',
#   'deathCnt': '70',
#   'defCnt': '3306',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '5',
#   'isolClearCnt': '3146',
#   'isolIngCnt': '90',
#   'localOccCnt': '5',
#   'overFlowCnt': '0',
#   'qurRate': '206.70',
#   'seq': '10431',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.325',
#   'deathCnt': '53',
#   'defCnt': '3559',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '15',
#   'isolClearCnt': '3337',
#   'isolIngCnt': '169',
#   'localOccCnt': '14',
#   'overFlowCnt': '1',
#   'qurRate': '231.02',
#   'seq': '10430',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.325',
#   'deathCnt': '654',
#   'defCnt': '44059',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '240',
#   'isolClearCnt': '41213',
#   'isolIngCnt': '2192',
#   'localOccCnt': '234',
#   'overFlowCnt': '6',
#   'qurRate': '332.51',
#   'seq': '10429',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.324',
#   'deathCnt': '1',
#   'defCnt': '560',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '3',
#   'isolClearCnt': '520',
#   'isolIngCnt': '39',
#   'localOccCnt': '3',
#   'overFlowCnt': '0',
#   'qurRate': '163.59',
#   'seq': '10428',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.324',
#   'deathCnt': '40',
#   'defCnt': '2824',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '4',
#   'isolClearCnt': '2689',
#   'isolIngCnt': '95',
#   'localOccCnt': '4',
#   'overFlowCnt': '0',
#   'qurRate': '246.20',
#   'seq': '10427',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.324',
#   'deathCnt': '27',
#   'defCnt': '2651',
#   'gubun': '대전',
#   'gubunCn': '大田',
#   'gubunEn': 'Daejeon',
#   'incDec': '26',
#   'isolClearCnt': '2394',
#   'isolIngCnt': '230',
#   'localOccCnt': '26',
#   'overFlowCnt': '0',
#   'qurRate': '179.83',
#   'seq': '10426',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.324',
#   'deathCnt': '24',
#   'defCnt': '2937',
#   'gubun': '광주',
#   'gubunCn': '光州',
#   'gubunEn': 'Gwangju',
#   'incDec': '6',
#   'isolClearCnt': '2859',
#   'isolIngCnt': '54',
#   'localOccCnt': '6',
#   'overFlowCnt': '0',
#   'qurRate': '201.62',
#   'seq': '10425',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.324',
#   'deathCnt': '61',
#   'defCnt': '6767',
#   'gubun': '인천',
#   'gubunCn': '仁川',
#   'gubunEn': 'Incheon',
#   'incDec': '30',
#   'isolClearCnt': '6462',
#   'isolIngCnt': '244',
#   'localOccCnt': '29',
#   'overFlowCnt': '1',
#   'qurRate': '228.92',
#   'seq': '10424',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.324',
#   'deathCnt': '222',
#   'defCnt': '10598',
#   'gubun': '대구',
#   'gubunCn': '大邱',
#   'gubunEn': 'Daegu',
#   'incDec': '11',
#   'isolClearCnt': '10294',
#   'isolIngCnt': '82',
#   'localOccCnt': '11',
#   'overFlowCnt': '0',
#   'qurRate': '434.97',
#   'seq': '10423',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.323',
#   'deathCnt': '124',
#   'defCnt': '6221',
#   'gubun': '부산',
#   'gubunCn': '釜山',
#   'gubunEn': 'Busan',
#   'incDec': '14',
#   'isolClearCnt': '5852',
#   'isolIngCnt': '245',
#   'localOccCnt': '13',
#   'overFlowCnt': '1',
#   'qurRate': '182.34',
#   'seq': '10422',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.323',
#   'deathCnt': '513',
#   'defCnt': '49987',
#   'gubun': '서울',
#   'gubunCn': '首尔',
#   'gubunEn': 'Seoul',
#   'incDec': '375',
#   'isolClearCnt': '46501',
#   'isolIngCnt': '2973',
#   'localOccCnt': '368',
#   'overFlowCnt': '7',
#   'qurRate': '513.56',
#   'seq': '10421',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-30 09:43:12.323',
#   'deathCnt': '2018',
#   'defCnt': '156961',
#   'gubun': '합계',
#   'gubunCn': '合计',
#   'gubunEn': 'Total',
#   'incDec': '794',
#   'isolClearCnt': '147693',
#   'isolIngCnt': '7250',
#   'localOccCnt': '759',
#   'overFlowCnt': '35',
#   'qurRate': '302.74',
#   'seq': '10420',
#   'stdDay': '2021년 06월 30일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.892',
#   'deathCnt': '5',
#   'defCnt': '4199',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '16',
#   'isolClearCnt': '3959',
#   'isolIngCnt': '235',
#   'localOccCnt': '0',
#   'overFlowCnt': '16',
#   'qurRate': '-',
#   'seq': '10419',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.892',
#   'deathCnt': '1',
#   'defCnt': '1262',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '6',
#   'isolClearCnt': '1217',
#   'isolIngCnt': '44',
#   'localOccCnt': '6',
#   'overFlowCnt': '0',
#   'qurRate': '188.15',
#   'seq': '10418',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.891',
#   'deathCnt': '20',
#   'defCnt': '5230',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '15',
#   'isolClearCnt': '5056',
#   'isolIngCnt': '154',
#   'localOccCnt': '13',
#   'overFlowCnt': '2',
#   'qurRate': '155.59',
#   'seq': '10417',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.891',
#   'deathCnt': '86',
#   'defCnt': '4945',
#   'gubun': '경북',
#   'gubunCn': '庆北',
#   'gubunEn': 'Gyeongsangbuk-do',
#   'incDec': '6',
#   'isolClearCnt': '4747',
#   'isolIngCnt': '112',
#   'localOccCnt': '5',
#   'overFlowCnt': '1',
#   'qurRate': '185.73',
#   'seq': '10416',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.891',
#   'deathCnt': '15',
#   'defCnt': '1641',
#   'gubun': '전남',
#   'gubunCn': '全南',
#   'gubunEn': 'Jeollanam-do',
#   'incDec': '4',
#   'isolClearCnt': '1524',
#   'isolIngCnt': '102',
#   'localOccCnt': '2',
#   'overFlowCnt': '2',
#   'qurRate': '88.00',
#   'seq': '10415',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.891',
#   'deathCnt': '59',
#   'defCnt': '2354',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '7',
#   'isolClearCnt': '2245',
#   'isolIngCnt': '50',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '129.53',
#   'seq': '10414',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.891',
#   'deathCnt': '42',
#   'defCnt': '3796',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '11',
#   'isolClearCnt': '3624',
#   'isolIngCnt': '130',
#   'localOccCnt': '11',
#   'overFlowCnt': '0',
#   'qurRate': '178.85',
#   'seq': '10413',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.891',
#   'deathCnt': '70',
#   'defCnt': '3301',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '10',
#   'isolClearCnt': '3135',
#   'isolIngCnt': '96',
#   'localOccCnt': '7',
#   'overFlowCnt': '3',
#   'qurRate': '206.39',
#   'seq': '10412',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.89',
#   'deathCnt': '53',
#   'defCnt': '3544',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '8',
#   'isolClearCnt': '3326',
#   'isolIngCnt': '165',
#   'localOccCnt': '8',
#   'overFlowCnt': '0',
#   'qurRate': '230.05',
#   'seq': '10411',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.89',
#   'deathCnt': '654',
#   'defCnt': '43819',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '230',
#   'isolClearCnt': '41107',
#   'isolIngCnt': '2058',
#   'localOccCnt': '228',
#   'overFlowCnt': '2',
#   'qurRate': '330.70',
#   'seq': '10410',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.89',
#   'deathCnt': '1',
#   'defCnt': '557',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '3',
#   'isolClearCnt': '518',
#   'isolIngCnt': '38',
#   'localOccCnt': '3',
#   'overFlowCnt': '0',
#   'qurRate': '162.71',
#   'seq': '10409',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.89',
#   'deathCnt': '40',
#   'defCnt': '2820',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '13',
#   'isolClearCnt': '2687',
#   'isolIngCnt': '93',
#   'localOccCnt': '13',
#   'overFlowCnt': '0',
#   'qurRate': '245.85',
#   'seq': '10408',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.89',
#   'deathCnt': '27',
#   'defCnt': '2625',
#   'gubun': '대전',
#   'gubunCn': '大田',
#   'gubunEn': 'Daejeon',
#   'incDec': '25',
#   'isolClearCnt': '2375',
#   'isolIngCnt': '223',
#   'localOccCnt': '25',
#   'overFlowCnt': '0',
#   'qurRate': '178.07',
#   'seq': '10407',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.89',
#   'deathCnt': '24',
#   'defCnt': '2931',
#   'gubun': '광주',
#   'gubunCn': '光州',
#   'gubunEn': 'Gwangju',
#   'incDec': '2',
#   'isolClearCnt': '2856',
#   'isolIngCnt': '51',
#   'localOccCnt': '2',
#   'overFlowCnt': '0',
#   'qurRate': '201.21',
#   'seq': '10406',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.89',
#   'deathCnt': '61',
#   'defCnt': '6737',
#   'gubun': '인천',
#   'gubunCn': '仁川',
#   'gubunEn': 'Incheon',
#   'incDec': '17',
#   'isolClearCnt': '6438',
#   'isolIngCnt': '238',
#   'localOccCnt': '17',
#   'overFlowCnt': '0',
#   'qurRate': '227.90',
#   'seq': '10405',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.889',
#   'deathCnt': '222',
#   'defCnt': '10587',
#   'gubun': '대구',
#   'gubunCn': '大邱',
#   'gubunEn': 'Daegu',
#   'incDec': '8',
#   'isolClearCnt': '10274',
#   'isolIngCnt': '91',
#   'localOccCnt': '6',
#   'overFlowCnt': '2',
#   'qurRate': '434.52',
#   'seq': '10404',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.889',
#   'deathCnt': '124',
#   'defCnt': '6207',
#   'gubun': '부산',
#   'gubunCn': '釜山',
#   'gubunEn': 'Busan',
#   'incDec': '9',
#   'isolClearCnt': '5838',
#   'isolIngCnt': '245',
#   'localOccCnt': '6',
#   'overFlowCnt': '3',
#   'qurRate': '181.93',
#   'seq': '10403',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.889',
#   'deathCnt': '513',
#   'defCnt': '49612',
#   'gubun': '서울',
#   'gubunCn': '首尔',
#   'gubunEn': 'Seoul',
#   'incDec': '205',
#   'isolClearCnt': '46151',
#   'isolIngCnt': '2948',
#   'localOccCnt': '201',
#   'overFlowCnt': '4',
#   'qurRate': '509.70',
#   'seq': '10402',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-29 09:53:26.889',
#   'deathCnt': '2017',
#   'defCnt': '156167',
#   'gubun': '합계',
#   'gubunCn': '合计',
#   'gubunEn': 'Total',
#   'incDec': '595',
#   'isolClearCnt': '147077',
#   'isolIngCnt': '7073',
#   'localOccCnt': '560',
#   'overFlowCnt': '35',
#   'qurRate': '301.20',
#   'seq': '10401',
#   'stdDay': '2021년 06월 29일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-28 09:42:55.213',
#   'deathCnt': '5',
#   'defCnt': '4183',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '11',
#   'isolClearCnt': '3910',
#   'isolIngCnt': '268',
#   'localOccCnt': '0',
#   'overFlowCnt': '11',
#   'qurRate': '-',
#   'seq': '10400',
#   'stdDay': '2021년 06월 28일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-28 09:42:55.213',
#   'deathCnt': '1',
#   'defCnt': '1256',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '2',
#   'isolClearCnt': '1212',
#   'isolIngCnt': '43',
#   'localOccCnt': '2',
#   'overFlowCnt': '0',
#   'qurRate': '187.25',
#   'seq': '10399',
#   'stdDay': '2021년 06월 28일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-28 09:42:55.213',
#   'deathCnt': '20',
#   'defCnt': '5215',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '10',
#   'isolClearCnt': '5040',
#   'isolIngCnt': '155',
#   'localOccCnt': '10',
#   'overFlowCnt': '0',
#   'qurRate': '155.15',
#   'seq': '10398',
#   'stdDay': '2021년 06월 28일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-06-28 09:42:55.213',
#   'deathCnt': '86',
#   'defCnt': '4939',
#   'gubun': '경북',
# ...
#   'qurRate': '69.5',
#   'seq': '9541',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.57',
#   'deathCnt': '58',
#   'defCnt': '2104',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '14',
#   'isolClearCnt': '1917',
#   'isolIngCnt': '129',
#   'localOccCnt': '13',
#   'overFlowCnt': '1',
#   'qurRate': '115.78',
#   'seq': '9540',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.57',
#   'deathCnt': '36',
#   'defCnt': '3256',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '18',
#   'isolClearCnt': '3031',
#   'isolIngCnt': '189',
#   'localOccCnt': '14',
#   'overFlowCnt': '4',
#   'qurRate': '153.41',
#   'seq': '9539',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.57',
#   'deathCnt': '68',
#   'defCnt': '2759',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '20',
#   'isolClearCnt': '2586',
#   'isolIngCnt': '105',
#   'localOccCnt': '19',
#   'overFlowCnt': '1',
#   'qurRate': '172.5',
#   'seq': '9538',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.57',
#   'deathCnt': '50',
#   'defCnt': '2919',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '5',
#   'isolClearCnt': '2677',
#   'isolIngCnt': '192',
#   'localOccCnt': '5',
#   'overFlowCnt': '0',
#   'qurRate': '189.48',
#   'seq': '9537',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.57',
#   'deathCnt': '617',
#   'defCnt': '36769',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '161',
#   'isolClearCnt': '33994',
#   'isolIngCnt': '2158',
#   'localOccCnt': '156',
#   'overFlowCnt': '5',
#   'qurRate': '277.49',
#   'seq': '9536',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.57',
#   'deathCnt': '1',
#   'defCnt': '399',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '0',
#   'isolClearCnt': '370',
#   'isolIngCnt': '28',
#   'localOccCnt': '0',
#   'overFlowCnt': '0',
#   'qurRate': '116.55',
#   'seq': '9535',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.569',
#   'deathCnt': '39',
#   'defCnt': '2368',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '11',
#   'isolClearCnt': '1994',
#   'isolIngCnt': '335',
#   'localOccCnt': '11',
#   'overFlowCnt': '0',
#   'qurRate': '206.44',
#   'seq': '9534',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.569',
#   'deathCnt': '20',
#   'defCnt': '1906',
#   'gubun': '대전',
#   'gubunCn': '大田',
#   'gubunEn': 'Daejeon',
#   'incDec': '4',
#   'isolClearCnt': '1750',
#   'isolIngCnt': '136',
#   'localOccCnt': '4',
#   'overFlowCnt': '0',
#   'qurRate': '129.29',
#   'seq': '9533',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.569',
#   'deathCnt': '22',
#   'defCnt': '2599',
#   'gubun': '광주',
#   'gubunCn': '光州',
#   'gubunEn': 'Gwangju',
#   'incDec': '14',
#   'isolClearCnt': '2442',
#   'isolIngCnt': '135',
#   'localOccCnt': '14',
#   'overFlowCnt': '0',
#   'qurRate': '178.42',
#   'seq': '9532',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.569',
#   'deathCnt': '60',
#   'defCnt': '5941',
#   'gubun': '인천',
#   'gubunCn': '仁川',
#   'gubunEn': 'Incheon',
#   'incDec': '15',
#   'isolClearCnt': '5679',
#   'isolIngCnt': '202',
#   'localOccCnt': '15',
#   'overFlowCnt': '0',
#   'qurRate': '200.97',
#   'seq': '9531',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.568',
#   'deathCnt': '221',
#   'defCnt': '9479',
#   'gubun': '대구',
#   'gubunCn': '大邱',
#   'gubunEn': 'Daegu',
#   'incDec': '6',
#   'isolClearCnt': '9177',
#   'isolIngCnt': '81',
#   'localOccCnt': '6',
#   'overFlowCnt': '0',
#   'qurRate': '389.04',
#   'seq': '9530',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.568',
#   'deathCnt': '122',
#   'defCnt': '5413',
#   'gubun': '부산',
#   'gubunCn': '釜山',
#   'gubunEn': 'Busan',
#   'incDec': '31',
#   'isolClearCnt': '5022',
#   'isolIngCnt': '269',
#   'localOccCnt': '30',
#   'overFlowCnt': '1',
#   'qurRate': '158.65',
#   'seq': '9529',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-16 09:36:28.568',
#   'deathCnt': '471',
#   'defCnt': '41042',
#   'gubun': '서울',
#   'gubunCn': '首尔',
#   'gubunEn': 'Seoul',
#   'incDec': '212',
#   'isolClearCnt': '37721',
#   'isolIngCnt': '2851',
#   'localOccCnt': '207',
#   'overFlowCnt': '5',
#   'qurRate': '421.67',
#   'seq': '9528',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': '2021-06-15 15:30:59.346'},
#  {'createDt': '2021-05-16 09:36:28.568',
#   'deathCnt': '1900',
#   'defCnt': '131670',
#   'gubun': '합계',
#   'gubunCn': '合计',
#   'gubunEn': 'Total',
#   'incDec': '609',
#   'isolClearCnt': '121764',
#   'isolIngCnt': '8007',
#   'localOccCnt': '571',
#   'overFlowCnt': '38',
#   'qurRate': '253.96',
#   'seq': '9527',
#   'stdDay': '2021년 05월 16일 00시',
#   'updateDt': '2021-06-15 15:30:59.346'},
#  {'createDt': '2021-05-15 09:50:45.441',
#   'deathCnt': '4',
#   'defCnt': '3649',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '9',
#   'isolClearCnt': '3434',
#   'isolIngCnt': '211',
#   'localOccCnt': '0',
#   'overFlowCnt': '9',
#   'qurRate': '0',
#   'seq': '9526',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.441',
#   'deathCnt': '1',
#   'defCnt': '862',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '14',
#   'isolClearCnt': '728',
#   'isolIngCnt': '133',
#   'localOccCnt': '14',
#   'overFlowCnt': '0',
#   'qurRate': '128.51',
#   'seq': '9525',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.441',
#   'deathCnt': '19',
#   'defCnt': '4388',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '40',
#   'isolClearCnt': '4058',
#   'isolIngCnt': '311',
#   'localOccCnt': '38',
#   'overFlowCnt': '2',
#   'qurRate': '130.54',
#   'seq': '9524',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.44',
#   'deathCnt': '79',
#   'defCnt': '4436',
#   'gubun': '경북',
#   'gubunCn': '庆北',
#   'gubunEn': 'Gyeongsangbuk-do',
#   'incDec': '19',
#   'isolClearCnt': '4089',
#   'isolIngCnt': '268',
#   'localOccCnt': '19',
#   'overFlowCnt': '0',
#   'qurRate': '166.61',
#   'seq': '9523',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.44',
#   'deathCnt': '12',
#   'defCnt': '1283',
#   'gubun': '전남',
#   'gubunCn': '全南',
#   'gubunEn': 'Jeollanam-do',
#   'incDec': '26',
#   'isolClearCnt': '1046',
#   'isolIngCnt': '225',
#   'localOccCnt': '26',
#   'overFlowCnt': '0',
#   'qurRate': '68.80',
#   'seq': '9522',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.44',
#   'deathCnt': '58',
#   'defCnt': '2090',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '11',
#   'isolClearCnt': '1909',
#   'isolIngCnt': '123',
#   'localOccCnt': '10',
#   'overFlowCnt': '1',
#   'qurRate': '115.01',
#   'seq': '9521',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.44',
#   'deathCnt': '36',
#   'defCnt': '3238',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '12',
#   'isolClearCnt': '3021',
#   'isolIngCnt': '181',
#   'localOccCnt': '10',
#   'overFlowCnt': '2',
#   'qurRate': '152.56',
#   'seq': '9520',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.44',
#   'deathCnt': '68',
#   'defCnt': '2739',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '5',
#   'isolClearCnt': '2579',
#   'isolIngCnt': '92',
#   'localOccCnt': '5',
#   'overFlowCnt': '0',
#   'qurRate': '171.25',
#   'seq': '9519',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.44',
#   'deathCnt': '50',
#   'defCnt': '2914',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '12',
#   'isolClearCnt': '2667',
#   'isolIngCnt': '197',
#   'localOccCnt': '12',
#   'overFlowCnt': '0',
#   'qurRate': '189.15',
#   'seq': '9518',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.439',
#   'deathCnt': '616',
#   'defCnt': '36608',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '170',
#   'isolClearCnt': '33868',
#   'isolIngCnt': '2124',
#   'localOccCnt': '168',
#   'overFlowCnt': '2',
#   'qurRate': '276.28',
#   'seq': '9517',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.439',
#   'deathCnt': '1',
#   'defCnt': '399',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '3',
#   'isolClearCnt': '370',
#   'isolIngCnt': '28',
#   'localOccCnt': '3',
#   'overFlowCnt': '0',
#   'qurRate': '116.55',
#   'seq': '9516',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.439',
#   'deathCnt': '39',
#   'defCnt': '2357',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '22',
#   'isolClearCnt': '1968',
#   'isolIngCnt': '350',
#   'localOccCnt': '22',
#   'overFlowCnt': '0',
#   'qurRate': '205.49',
#   'seq': '9515',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.439',
#   'deathCnt': '20',
#   'defCnt': '1902',
#   'gubun': '대전',
#   'gubunCn': '大田',
#   'gubunEn': 'Daejeon',
#   'incDec': '10',
#   'isolClearCnt': '1733',
#   'isolIngCnt': '149',
#   'localOccCnt': '10',
#   'overFlowCnt': '0',
#   'qurRate': '129.02',
#   'seq': '9514',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.439',
#   'deathCnt': '22',
#   'defCnt': '2585',
#   'gubun': '광주',
#   'gubunCn': '光州',
#   'gubunEn': 'Gwangju',
#   'incDec': '11',
#   'isolClearCnt': '2423',
#   'isolIngCnt': '140',
#   'localOccCnt': '10',
#   'overFlowCnt': '1',
#   'qurRate': '177.46',
#   'seq': '9513',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.439',
#   'deathCnt': '60',
#   'defCnt': '5926',
#   'gubun': '인천',
#   'gubunCn': '仁川',
#   'gubunEn': 'Incheon',
#   'incDec': '16',
#   'isolClearCnt': '5668',
#   'isolIngCnt': '198',
#   'localOccCnt': '16',
#   'overFlowCnt': '0',
#   'qurRate': '200.47',
#   'seq': '9512',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.438',
#   'deathCnt': '221',
#   'defCnt': '9473',
#   'gubun': '대구',
#   'gubunCn': '大邱',
#   'gubunEn': 'Daegu',
#   'incDec': '5',
#   'isolClearCnt': '9168',
#   'isolIngCnt': '84',
#   'localOccCnt': '4',
#   'overFlowCnt': '1',
#   'qurRate': '388.80',
#   'seq': '9511',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.438',
#   'deathCnt': '122',
#   'defCnt': '5382',
#   'gubun': '부산',
#   'gubunCn': '釜山',
#   'gubunEn': 'Busan',
#   'incDec': '42',
#   'isolClearCnt': '4996',
#   'isolIngCnt': '264',
#   'localOccCnt': '41',
#   'overFlowCnt': '1',
#   'qurRate': '157.75',
#   'seq': '9510',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-15 09:50:45.438',
#   'deathCnt': '468',
#   'defCnt': '40829',
#   'gubun': '서울',
#   'gubunCn': '首尔',
#   'gubunEn': 'Seoul',
#   'incDec': '253',
#   'isolClearCnt': '37557',
#   'isolIngCnt': '2805',
#   'localOccCnt': '252',
#   'overFlowCnt': '1',
#   'qurRate': '419.48',
#   'seq': '9509',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': '2021-06-15 15:30:59.346'},
#  {'createDt': '2021-05-15 09:50:45.438',
#   'deathCnt': '1896',
#   'defCnt': '131060',
#   'gubun': '합계',
#   'gubunCn': '合计',
#   'gubunEn': 'Total',
#   'incDec': '680',
#   'isolClearCnt': '121282',
#   'isolIngCnt': '7883',
#   'localOccCnt': '660',
#   'overFlowCnt': '20',
#   'qurRate': '252.78',
#   'seq': '9508',
#   'stdDay': '2021년 05월 15일 00시',
#   'updateDt': '2021-06-15 15:30:59.346'},
#  {'createDt': '2021-05-14 09:38:52.496',
#   'deathCnt': '4',
#   'defCnt': '3640',
#   'gubun': '검역',
#   'gubunCn': '隔離區',
#   'gubunEn': 'Lazaretto',
#   'incDec': '9',
#   'isolClearCnt': '3434',
#   'isolIngCnt': '202',
#   'localOccCnt': '0',
#   'overFlowCnt': '9',
#   'qurRate': '-',
#   'seq': '9507',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.496',
#   'deathCnt': '1',
#   'defCnt': '848',
#   'gubun': '제주',
#   'gubunCn': '济州',
#   'gubunEn': 'Jeju',
#   'incDec': '10',
#   'isolClearCnt': '719',
#   'isolIngCnt': '128',
#   'localOccCnt': '10',
#   'overFlowCnt': '0',
#   'qurRate': '126.43',
#   'seq': '9506',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.496',
#   'deathCnt': '19',
#   'defCnt': '4348',
#   'gubun': '경남',
#   'gubunCn': '庆南',
#   'gubunEn': 'Gyeongsangnam-do',
#   'incDec': '32',
#   'isolClearCnt': '4021',
#   'isolIngCnt': '308',
#   'localOccCnt': '28',
#   'overFlowCnt': '4',
#   'qurRate': '129.35',
#   'seq': '9505',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.496',
#   'deathCnt': '79',
#   'defCnt': '4417',
#   'gubun': '경북',
#   'gubunCn': '庆北',
#   'gubunEn': 'Gyeongsangbuk-do',
#   'incDec': '35',
#   'isolClearCnt': '4057',
#   'isolIngCnt': '281',
#   'localOccCnt': '34',
#   'overFlowCnt': '1',
#   'qurRate': '165.90',
#   'seq': '9504',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.496',
#   'deathCnt': '12',
#   'defCnt': '1257',
#   'gubun': '전남',
#   'gubunCn': '全南',
#   'gubunEn': 'Jeollanam-do',
#   'incDec': '50',
#   'isolClearCnt': '1039',
#   'isolIngCnt': '206',
#   'localOccCnt': '50',
#   'overFlowCnt': '0',
#   'qurRate': '67.41',
#   'seq': '9503',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.495',
#   'deathCnt': '58',
#   'defCnt': '2079',
#   'gubun': '전북',
#   'gubunCn': '全北',
#   'gubunEn': 'Jeollabuk-do',
#   'incDec': '14',
#   'isolClearCnt': '1900',
#   'isolIngCnt': '121',
#   'localOccCnt': '14',
#   'overFlowCnt': '0',
#   'qurRate': '114.40',
#   'seq': '9502',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.495',
#   'deathCnt': '36',
#   'defCnt': '3226',
#   'gubun': '충남',
#   'gubunCn': '忠南',
#   'gubunEn': 'Chungcheongnam-do',
#   'incDec': '22',
#   'isolClearCnt': '3006',
#   'isolIngCnt': '184',
#   'localOccCnt': '22',
#   'overFlowCnt': '0',
#   'qurRate': '151.99',
#   'seq': '9501',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.495',
#   'deathCnt': '67',
#   'defCnt': '2734',
#   'gubun': '충북',
#   'gubunCn': '忠北',
#   'gubunEn': 'Chungcheongbuk-do',
#   'incDec': '4',
#   'isolClearCnt': '2574',
#   'isolIngCnt': '93',
#   'localOccCnt': '4',
#   'overFlowCnt': '0',
#   'qurRate': '170.94',
#   'seq': '9500',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.495',
#   'deathCnt': '50',
#   'defCnt': '2902',
#   'gubun': '강원',
#   'gubunCn': '江原',
#   'gubunEn': 'Gangwon-do',
#   'incDec': '25',
#   'isolClearCnt': '2650',
#   'isolIngCnt': '202',
#   'localOccCnt': '25',
#   'overFlowCnt': '0',
#   'qurRate': '188.38',
#   'seq': '9499',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.495',
#   'deathCnt': '615',
#   'defCnt': '36438',
#   'gubun': '경기',
#   'gubunCn': '京畿',
#   'gubunEn': 'Gyeonggi-do',
#   'incDec': '173',
#   'isolClearCnt': '33599',
#   'isolIngCnt': '2224',
#   'localOccCnt': '172',
#   'overFlowCnt': '1',
#   'qurRate': '275.00',
#   'seq': '9498',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.495',
#   'deathCnt': '1',
#   'defCnt': '396',
#   'gubun': '세종',
#   'gubunCn': '世宗',
#   'gubunEn': 'Sejong',
#   'incDec': '7',
#   'isolClearCnt': '368',
#   'isolIngCnt': '27',
#   'localOccCnt': '7',
#   'overFlowCnt': '0',
#   'qurRate': '115.68',
#   'seq': '9497',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  {'createDt': '2021-05-14 09:38:52.495',
#   'deathCnt': '38',
#   'defCnt': '2335',
#   'gubun': '울산',
#   'gubunCn': '蔚山',
#   'gubunEn': 'Ulsan',
#   'incDec': '26',
#   'isolClearCnt': '1934',
#   'isolIngCnt': '363',
#   'localOccCnt': '26',
#   'overFlowCnt': '0',
#   'qurRate': '203.57',
#   'seq': '9496',
#   'stdDay': '2021년 05월 14일 00시',
#   'updateDt': 'null'},
#  ...]

# %%
item = response_content['response']['body']['items']['item']
df = pd.DataFrame(item)
df.to_csv('/content/drive/코로나(시.도).csv', index = False)
