# %% [markdown]
# <a href="https://colab.research.google.com/github/cabbi120101/TIL/blob/master/%EA%B3%B5%EB%AA%A8%EC%A0%84%EA%B3%B5%EB%B6%80/%EC%BD%94%EB%A1%9C%EB%82%98(%EA%B0%90%EC%97%BC%ED%98%84%ED%99%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 ! pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (0.12.0)

# %%
from urllib.request import urlopen, Request
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다

# %%
key = ''

num_of_rows = 10 # 한페이지에 포함된 결과 수 
page_no = 1 #페이지 번호
url = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson'
start_Date = 20190101
end_Date = 20210705

req_parameter = '?' + urlencode({
    'serviceKey':  key,
    'numOfRows' : num_of_rows,
    'pageNo' : page_no,
    'startCreateDt' : start_Date,
    'endCreateDt' : end_Date,
})

r = requests.get(url + req_parameter)
response_content = json.loads(json.dumps(xmltodict.parse(r.text)))
response_content['response']['body']['items']['item']
# Out:
# [{'accDefRate': '1.5219245826',
#   'accExamCnt': '10700134',
#   'accExamCompCnt': '10565241',
#   'careCnt': '8723',
#   'clearCnt': '150044',
#   'createDt': '2021-07-05 09:53:08.163',
#   'deathCnt': '2028',
#   'decideCnt': '160795',
#   'examCnt': '134893',
#   'resutlNegCnt': '10404446',
#   'seq': '563',
#   'stateDt': '20210705',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.5175524712',
#   'accExamCnt': '10685125',
#   'accExamCompCnt': '10548828',
#   'careCnt': '8444',
#   'clearCnt': '149614',
#   'createDt': '2021-07-04 09:33:38.815',
#   'deathCnt': '2026',
#   'decideCnt': '160084',
#   'examCnt': '136297',
#   'resutlNegCnt': '10388744',
#   'seq': '562',
#   'stateDt': '20210704',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.5122560101',
#   'accExamCnt': '10670617',
#   'accExamCompCnt': '10536708',
#   'careCnt': '8185',
#   'clearCnt': '149132',
#   'createDt': '2021-07-03 09:44:37.172',
#   'deathCnt': '2025',
#   'decideCnt': '159342',
#   'examCnt': '133909',
#   'resutlNegCnt': '10377366',
#   'seq': '561',
#   'stateDt': '20210703',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.5084099075',
#   'accExamCnt': '10641602',
#   'accExamCompCnt': '10510936',
#   'careCnt': '8205',
#   'clearCnt': '148319',
#   'createDt': '2021-07-02 09:40:45.284',
#   'deathCnt': '2024',
#   'decideCnt': '158548',
#   'examCnt': '130666',
#   'resutlNegCnt': '10352388',
#   'seq': '560',
#   'stateDt': '20210702',
#   'stateTime': '00:00',
#   'updateDt': '2021-07-03 09:47:37.632'},
#  {'accDefRate': '1.5036335283',
#   'accExamCnt': '10614316',
#   'accExamCompCnt': '10489391',
#   'careCnt': '7677',
#   'clearCnt': '148024',
#   'createDt': '2021-07-01 09:42:01.927',
#   'deathCnt': '2021',
#   'decideCnt': '157722',
#   'examCnt': '124925',
#   'resutlNegCnt': '10331669',
#   'seq': '559',
#   'stateDt': '20210701',
#   'stateTime': '00:00',
#   'updateDt': '2021-07-03 09:46:43.839'},
#  {'accDefRate': '1.4998716669',
#   'accExamCnt': '10579072',
#   'accExamCompCnt': '10464962',
#   'careCnt': '7250',
#   'clearCnt': '147693',
#   'createDt': '2021-06-30 09:38:19.271',
#   'deathCnt': '2018',
#   'decideCnt': '156961',
#   'examCnt': '114110',
#   'resutlNegCnt': '10308001',
#   'seq': '558',
#   'stateDt': '20210630',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4960125523',
#   'accExamCnt': '10555741',
#   'accExamCompCnt': '10438883',
#   'careCnt': '7073',
#   'clearCnt': '147077',
#   'createDt': '2021-06-29 09:55:20.921',
#   'deathCnt': '2017',
#   'decideCnt': '156167',
#   'examCnt': '116858',
#   'resutlNegCnt': '10282716',
#   'seq': '557',
#   'stateDt': '20210629',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4950097471',
#   'accExamCnt': '10520929',
#   'accExamCompCnt': '10406086',
#   'careCnt': '6882',
#   'clearCnt': '146675',
#   'createDt': '2021-06-28 09:37:00.101',
#   'deathCnt': '2015',
#   'decideCnt': '155572',
#   'examCnt': '114843',
#   'resutlNegCnt': '10250514',
#   'seq': '556',
#   'stateDt': '20210628',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4921718017',
#   'accExamCnt': '10508678',
#   'accExamCompCnt': '10392302',
#   'careCnt': '6718',
#   'clearCnt': '146340',
#   'createDt': '2021-06-27 09:32:43.7',
#   'deathCnt': '2013',
#   'decideCnt': '155071',
#   'examCnt': '116376',
#   'resutlNegCnt': '10237231',
#   'seq': '555',
#   'stateDt': '20210627',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4878898766',
#   'accExamCnt': '10495516',
#   'accExamCompCnt': '10380943',
#   'careCnt': '6456',
#   'clearCnt': '145989',
#   'createDt': '2021-06-26 09:46:37.249',
#   'deathCnt': '2012',
#   'decideCnt': '154457',
#   'examCnt': '114573',
#   'resutlNegCnt': '10226486',
#   'seq': '554',
#   'stateDt': '20210626',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4866946297',
#   'accExamCnt': '10466545',
#   'accExamCompCnt': '10344357',
#   'careCnt': '6391',
#   'clearCnt': '145389',
#   'createDt': '2021-06-25 09:38:45.327',
#   'deathCnt': '2009',
#   'decideCnt': '153789',
#   'examCnt': '122188',
#   'resutlNegCnt': '10190568',
#   'seq': '553',
#   'stateDt': '20210625',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4843749318',
#   'accExamCnt': '10438782',
#   'accExamCompCnt': '10317811',
#   'careCnt': '6359',
#   'clearCnt': '144788',
#   'createDt': '2021-06-24 09:34:00.179',
#   'deathCnt': '2008',
#   'decideCnt': '153155',
#   'examCnt': '120971',
#   'resutlNegCnt': '10164656',
#   'seq': '552',
#   'stateDt': '20210624',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4838779715',
#   'accExamCnt': '10409949',
#   'accExamCompCnt': '10280158',
#   'careCnt': '6159',
#   'clearCnt': '144379',
#   'createDt': '2021-06-23 09:38:51.681',
#   'deathCnt': '2007',
#   'decideCnt': '152545',
#   'examCnt': '129791',
#   'resutlNegCnt': '10127613',
#   'seq': '551',
#   'stateDt': '20210623',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4815298868',
#   'accExamCnt': '10380042',
#   'accExamCompCnt': '10252915',
#   'careCnt': '6077',
#   'clearCnt': '143817',
#   'createDt': '2021-06-22 09:37:35.096',
#   'deathCnt': '2006',
#   'decideCnt': '151900',
#   'examCnt': '127127',
#   'resutlNegCnt': '10101015',
#   'seq': '550',
#   'stateDt': '20210622',
#   'stateTime': '00:00',
#   'updateDt': '2021-06-23 10:15:06.465'},
#  {'accDefRate': '1.4827923622',
#   'accExamCnt': '10346047',
#   'accExamCompCnt': '10217614',
#   'careCnt': '6234',
#   'clearCnt': '143268',
#   'createDt': '2021-06-21 09:40:21.025',
#   'deathCnt': '2004',
#   'decideCnt': '151506',
#   'examCnt': '128433',
#   'resutlNegCnt': '10066108',
#   'seq': '549',
#   'stateDt': '20210621',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4811890199',
#   'accExamCnt': '10335634',
#   'accExamCompCnt': '10204572',
#   'careCnt': '6248',
#   'clearCnt': '142899',
#   'createDt': '2021-06-20 09:39:22.589',
#   'deathCnt': '2002',
#   'decideCnt': '151149',
#   'examCnt': '131062',
#   'resutlNegCnt': '10053423',
#   'seq': '548',
#   'stateDt': '20210620',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4784539758',
#   'accExamCnt': '10323154',
#   'accExamCompCnt': '10194433',
#   'careCnt': '6338',
#   'clearCnt': '142385',
#   'createDt': '2021-06-19 09:54:16.488',
#   'deathCnt': '1997',
#   'decideCnt': '150720',
#   'examCnt': '128721',
#   'resutlNegCnt': '10043713',
#   'seq': '547',
#   'stateDt': '20210619',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4775263809',
#   'accExamCnt': '10294048',
#   'accExamCompCnt': '10168211',
#   'careCnt': '6426',
#   'clearCnt': '141816',
#   'createDt': '2021-06-18 09:42:02.1',
#   'deathCnt': '1996',
#   'decideCnt': '150238',
#   'examCnt': '125837',
#   'resutlNegCnt': '10017973',
#   'seq': '546',
#   'stateDt': '20210618',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4771444668',
#   'accExamCnt': '10257836',
#   'accExamCompCnt': '10136517',
#   'careCnt': '6708',
#   'clearCnt': '141029',
#   'createDt': '2021-06-17 09:37:38.734',
#   'deathCnt': '1994',
#   'decideCnt': '149731',
#   'examCnt': '121319',
#   'resutlNegCnt': '9986786',
#   'seq': '545',
#   'stateDt': '20210617',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4755870559',
#   'accExamCnt': '10229384',
#   'accExamCompCnt': '10110620',
#   'careCnt': '6760',
#   'clearCnt': '140438',
#   'createDt': '2021-06-16 09:52:02.014',
#   'deathCnt': '1993',
#   'decideCnt': '149191',
#   'examCnt': '118764',
#   'resutlNegCnt': '9961429',
#   'seq': '544',
#   'stateDt': '20210616',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4757160493',
#   'accExamCnt': '10196469',
#   'accExamCompCnt': '10072805',
#   'careCnt': '6921',
#   'clearCnt': '139733',
#   'createDt': '2021-06-15 09:34:07.292',
#   'deathCnt': '1992',
#   'decideCnt': '148646',
#   'examCnt': '123664',
#   'resutlNegCnt': '9924159',
#   'seq': '543',
#   'stateDt': '20210615',
#   'stateTime': '00:00',
#   'updateDt': '2021-06-16 09:46:35.159'},
#  {'accDefRate': '1.4765178464',
#   'accExamCnt': '10165497',
#   'accExamCompCnt': '10042073',
#   'careCnt': '7263',
#   'clearCnt': '139022',
#   'createDt': '2021-06-14 09:35:03.394',
#   'deathCnt': '1988',
#   'decideCnt': '148273',
#   'examCnt': '123424',
#   'resutlNegCnt': '9893800',
#   'seq': '542',
#   'stateDt': '20210614',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4745537419',
#   'accExamCnt': '10152907',
#   'accExamCompCnt': '10028390',
#   'careCnt': '7308',
#   'clearCnt': '138581',
#   'createDt': '2021-06-13 09:36:35.692',
#   'deathCnt': '1985',
#   'decideCnt': '147874',
#   'examCnt': '124517',
#   'resutlNegCnt': '9880516',
#   'seq': '541',
#   'stateDt': '20210613',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4715219644',
#   'accExamCnt': '10140535',
#   'accExamCompCnt': '10018335',
#   'careCnt': '7403',
#   'clearCnt': '138037',
#   'createDt': '2021-06-12 09:40:24.954',
#   'deathCnt': '1982',
#   'decideCnt': '147422',
#   'examCnt': '122200',
#   'resutlNegCnt': '9870913',
#   'seq': '540',
#   'stateDt': '20210612',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4719099107',
#   'accExamCnt': '10111062',
#   'accExamCompCnt': '9977309',
#   'careCnt': '7652',
#   'clearCnt': '137224',
#   'createDt': '2021-06-11 09:37:57.985',
#   'deathCnt': '1981',
#   'decideCnt': '146857',
#   'examCnt': '133753',
#   'resutlNegCnt': '9830452',
#   'seq': '539',
#   'stateDt': '20210611',
#   'stateTime': '00:00',
#   'updateDt': '2021-06-12 14:51:25.402'},
#  {'accDefRate': '1.4708941354',
#   'accExamCnt': '10076862',
#   'accExamCompCnt': '9946535',
#   'careCnt': '7611',
#   'clearCnt': '136713',
#   'createDt': '2021-06-10 09:35:53.948',
#   'deathCnt': '1979',
#   'decideCnt': '146303',
#   'examCnt': '130327',
#   'resutlNegCnt': '9800232',
#   'seq': '538',
#   'stateDt': '20210610',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4696532224',
#   'accExamCnt': '10044783',
#   'accExamCompCnt': '9913359',
#   'careCnt': '7541',
#   'clearCnt': '136174',
#   'createDt': '2021-06-09 09:41:30.049',
#   'deathCnt': '1977',
#   'decideCnt': '145692',
#   'examCnt': '131424',
#   'resutlNegCnt': '9767667',
#   'seq': '537',
#   'stateDt': '20210609',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4701109691',
#   'accExamCnt': '10008583',
#   'accExamCompCnt': '9869323',
#   'careCnt': '7703',
#   'clearCnt': '135412',
#   'createDt': '2021-06-08 09:37:18.147',
#   'deathCnt': '1975',
#   'decideCnt': '145090',
#   'examCnt': '139260',
#   'resutlNegCnt': '9724233',
#   'seq': '536',
#   'stateDt': '20210608',
#   'stateTime': '00:00',
#   'updateDt': '2021-06-09 16:41:53.988'},
#  {'accDefRate': '1.4705202062',
#   'accExamCnt': '9972297',
#   'accExamCompCnt': '9835771',
#   'careCnt': '7802',
#   'clearCnt': '134861',
#   'createDt': '2021-06-07 09:34:49.979',
#   'deathCnt': '1974',
#   'decideCnt': '144637',
#   'examCnt': '136526',
#   'resutlNegCnt': '9691134',
#   'seq': '535',
#   'stateDt': '20210607',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4674599968',
#   'accExamCnt': '9959697',
#   'accExamCompCnt': '9823232',
#   'careCnt': '7917',
#   'clearCnt': '134262',
#   'createDt': '2021-06-06 09:43:04.144',
#   'deathCnt': '1973',
#   'decideCnt': '144152',
#   'examCnt': '136465',
#   'resutlNegCnt': '9679080',
#   'seq': '534',
#   'stateDt': '20210606',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4639522306',
#   'accExamCnt': '9945954',
#   'accExamCompCnt': '9808790',
#   'careCnt': '7862',
#   'clearCnt': '133763',
#   'createDt': '2021-06-05 09:35:32.811',
#   'deathCnt': '1971',
#   'decideCnt': '143596',
#   'examCnt': '137164',
#   'resutlNegCnt': '9665194',
#   'seq': '533',
#   'stateDt': '20210605',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4610308586',
#   'accExamCnt': '9911324',
#   'accExamCompCnt': '9777480',
#   'careCnt': '7594',
#   'clearCnt': '133289',
#   'createDt': '2021-06-04 09:35:01.747',
#   'deathCnt': '1969',
#   'decideCnt': '142852',
#   'examCnt': '133844',
#   'resutlNegCnt': '9634628',
#   'seq': '532',
#   'stateDt': '20210604',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4591426309',
#   'accExamCnt': '9872324',
#   'accExamCompCnt': '9742502',
#   'careCnt': '7490',
#   'clearCnt': '132699',
#   'createDt': '2021-06-03 09:34:41.776',
#   'deathCnt': '1968',
#   'decideCnt': '142157',
#   'examCnt': '129822',
#   'resutlNegCnt': '9600345',
#   'seq': '531',
#   'stateDt': '20210603',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4576990021',
#   'accExamCnt': '9834350',
#   'accExamCompCnt': '9705433',
#   'careCnt': '7443',
#   'clearCnt': '132068',
#   'createDt': '2021-06-02 09:34:39.577',
#   'deathCnt': '1965',
#   'decideCnt': '141476',
#   'examCnt': '128917',
#   'resutlNegCnt': '9563957',
#   'seq': '530',
#   'stateDt': '20210602',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4559203539',
#   'accExamCnt': '9798402',
#   'accExamCompCnt': '9670790',
#   'careCnt': '7373',
#   'clearCnt': '131463',
#   'createDt': '2021-06-01 09:39:17.218',
#   'deathCnt': '1963',
#   'decideCnt': '140799',
#   'examCnt': '127612',
#   'resutlNegCnt': '9529991',
#   'seq': '529',
#   'stateDt': '20210601',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4568360166',
#   'accExamCnt': '9761158',
#   'accExamCompCnt': '9633205',
#   'careCnt': '7558',
#   'clearCnt': '130823',
#   'createDt': '2021-05-31 09:34:29.254',
#   'deathCnt': '1959',
#   'decideCnt': '140340',
#   'examCnt': '127953',
#   'resutlNegCnt': '9492865',
#   'seq': '528',
#   'stateDt': '20210531',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4541964496',
#   'accExamCnt': '9747614',
#   'accExamCompCnt': '9621121',
#   'careCnt': '7572',
#   'clearCnt': '130381',
#   'createDt': '2021-05-30 09:24:39.384',
#   'deathCnt': '1957',
#   'decideCnt': '139910',
#   'examCnt': '126493',
#   'resutlNegCnt': '9481211',
#   'seq': '527',
#   'stateDt': '20210530',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4509249463',
#   'accExamCnt': '9733591',
#   'accExamCompCnt': '9609801',
#   'careCnt': '7741',
#   'clearCnt': '129739',
#   'createDt': '2021-05-29 09:45:26.765',
#   'deathCnt': '1951',
#   'decideCnt': '139431',
#   'examCnt': '123790',
#   'resutlNegCnt': '9470370',
#   'seq': '526',
#   'stateDt': '20210529',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4499377008',
#   'accExamCnt': '9702456',
#   'accExamCompCnt': '9579584',
#   'careCnt': '8193',
#   'clearCnt': '128759',
#   'createDt': '2021-05-28 09:34:29.553',
#   'deathCnt': '1946',
#   'decideCnt': '138898',
#   'examCnt': '122872',
#   'resutlNegCnt': '9440686',
#   'seq': '525',
#   'stateDt': '20210528',
#   'stateTime': '00:00',
#   'updateDt': '2021-05-29 09:47:35.466'},
#  {'accDefRate': '1.4493399059',
#   'accExamCnt': '9665693',
#   'accExamCompCnt': '9543034',
#   'careCnt': '8188',
#   'clearCnt': '128180',
#   'createDt': '2021-05-27 09:39:43.099',
#   'deathCnt': '1943',
#   'decideCnt': '138311',
#   'examCnt': '122659',
#   'resutlNegCnt': '9404723',
#   'seq': '524',
#   'stateDt': '20210527',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4479226274',
#   'accExamCnt': '9629450',
#   'accExamCompCnt': '9508381',
#   'careCnt': '8160',
#   'clearCnt': '127574',
#   'createDt': '2021-05-26 09:46:42.628',
#   'deathCnt': '1940',
#   'decideCnt': '137674',
#   'examCnt': '121069',
#   'resutlNegCnt': '9370707',
#   'seq': '523',
#   'stateDt': '20210526',
#   'stateTime': '00:00',
#   'updateDt': '2021-05-27 09:40:52.468'},
#  {'accDefRate': '1.4455504748',
#   'accExamCnt': '9592727',
#   'accExamCompCnt': '9475629',
#   'careCnt': '8044',
#   'clearCnt': '126993',
#   'createDt': '2021-05-25 09:33:39.762',
#   'deathCnt': '1938',
#   'decideCnt': '136975',
#   'examCnt': '117098',
#   'resutlNegCnt': '9338654',
#   'seq': '522',
#   'stateDt': '20210525',
#   'stateTime': '00:00',
#   'updateDt': '2021-05-26 17:26:57.787'},
#  {'accDefRate': '1.4466269101',
#   'accExamCnt': '9553613',
#   'accExamCompCnt': '9432909',
#   'careCnt': '8098',
#   'clearCnt': '126427',
#   'createDt': '2021-05-24 09:42:11.785',
#   'deathCnt': '1934',
#   'decideCnt': '136459',
#   'examCnt': '120704',
#   'resutlNegCnt': '9296450',
#   'seq': '521',
#   'stateDt': '20210524',
#   'stateTime': '00:00',
#   'updateDt': '2021-05-26 17:11:27.494'},
#  {'accDefRate': '1.4438928819',
#   'accExamCnt': '9536299',
#   'accExamCompCnt': '9414064',
#   'careCnt': '8117',
#   'clearCnt': '125881',
#   'createDt': '2021-05-23 09:37:54.099',
#   'deathCnt': '1931',
#   'decideCnt': '135929',
#   'examCnt': '122235',
#   'resutlNegCnt': '9278135',
#   'seq': '520',
#   'stateDt': '20210523',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4393079615',
#   'accExamCnt': '9520966',
#   'accExamCompCnt': '9403408',
#   'careCnt': '8386',
#   'clearCnt': '125032',
#   'createDt': '2021-05-22 09:37:01.885',
#   'deathCnt': '1926',
#   'decideCnt': '135344',
#   'examCnt': '117558',
#   'resutlNegCnt': '9268064',
#   'seq': '519',
#   'stateDt': '20210522',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4368773847',
#   'accExamCnt': '9487108',
#   'accExamCompCnt': '9372964',
#   'careCnt': '8598',
#   'clearCnt': '124158',
#   'createDt': '2021-05-21 09:36:32.023',
#   'deathCnt': '1922',
#   'decideCnt': '134678',
#   'examCnt': '114144',
#   'resutlNegCnt': '9238286',
#   'seq': '518',
#   'stateDt': '20210521',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4361751397',
#   'accExamCnt': '9447358',
#   'accExamCompCnt': '9338485',
#   'careCnt': '8542',
#   'clearCnt': '123659',
#   'createDt': '2021-05-20 09:35:45.542',
#   'deathCnt': '1916',
#   'decideCnt': '134117',
#   'examCnt': '108873',
#   'resutlNegCnt': '9204368',
#   'seq': '517',
#   'stateDt': '20210520',
#   'stateTime': '00:00',
#   'updateDt': '2021-05-21 09:47:58.875'},
#  {'accDefRate': '1.4314548779',
#   'accExamCnt': '9428644',
#   'accExamCompCnt': '9324150',
#   'careCnt': '8322',
#   'clearCnt': '123237',
#   'createDt': '2021-05-19 09:39:48.186',
#   'deathCnt': '1912',
#   'decideCnt': '133471',
#   'examCnt': '104494',
#   'resutlNegCnt': '9190679',
#   'seq': '516',
#   'stateDt': '20210519',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4294430308',
#   'accExamCnt': '9395004',
#   'accExamCompCnt': '9291591',
#   'careCnt': '8283',
#   'clearCnt': '122631',
#   'createDt': '2021-05-18 09:41:35.393',
#   'deathCnt': '1904',
#   'decideCnt': '132818',
#   'examCnt': '103413',
#   'resutlNegCnt': '9158773',
#   'seq': '515',
#   'stateDt': '20210518',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4299308998',
#   'accExamCnt': '9353300',
#   'accExamCompCnt': '9251496',
#   'careCnt': '8224',
#   'clearCnt': '122163',
#   'createDt': '2021-05-17 09:39:34.169',
#   'deathCnt': '1903',
#   'decideCnt': '132290',
#   'examCnt': '101804',
#   'resutlNegCnt': '9119206',
#   'seq': '514',
#   'stateDt': '20210517',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4257899148',
#   'accExamCnt': '9336614',
#   'accExamCompCnt': '9234951',
#   'careCnt': '8007',
#   'clearCnt': '121764',
#   'createDt': '2021-05-16 09:26:31.589',
#   'deathCnt': '1900',
#   'decideCnt': '131671',
#   'examCnt': '101663',
#   'resutlNegCnt': '9103280',
#   'seq': '513',
#   'stateDt': '20210516',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4215047097',
#   'accExamCnt': '9319094',
#   'accExamCompCnt': '9219878',
#   'careCnt': '7883',
#   'clearCnt': '121282',
#   'createDt': '2021-05-15 09:38:53.579',
#   'deathCnt': '1896',
#   'decideCnt': '131061',
#   'examCnt': '99216',
#   'resutlNegCnt': '9088817',
#   'seq': '512',
#   'stateDt': '20210515',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4193209445',
#   'accExamCnt': '9281291',
#   'accExamCompCnt': '9186083',
#   'careCnt': '8092',
#   'clearCnt': '120395',
#   'createDt': '2021-05-14 09:44:47.494',
#   'deathCnt': '1893',
#   'decideCnt': '130380',
#   'examCnt': '95208',
#   'resutlNegCnt': '9055703',
#   'seq': '511',
#   'stateDt': '20210514',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4161913364',
#   'accExamCnt': '9241153',
#   'accExamCompCnt': '9153636',
#   'careCnt': '7836',
#   'clearCnt': '119906',
#   'createDt': '2021-05-13 09:41:10.7',
#   'deathCnt': '1891',
#   'decideCnt': '129633',
#   'examCnt': '87517',
#   'resutlNegCnt': '9024003',
#   'seq': '510',
#   'stateDt': '20210513',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4139993813',
#   'accExamCnt': '9201539',
#   'accExamCompCnt': '9117260',
#   'careCnt': '7661',
#   'clearCnt': '119373',
#   'createDt': '2021-05-12 09:38:47.792',
#   'deathCnt': '1884',
#   'decideCnt': '128918',
#   'examCnt': '84279',
#   'resutlNegCnt': '8988342',
#   'seq': '509',
#   'stateDt': '20210512',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4128508833',
#   'accExamCnt': '9164284',
#   'accExamCompCnt': '9079656',
#   'careCnt': '7686',
#   'clearCnt': '118717',
#   'createDt': '2021-05-11 09:39:41.186',
#   'deathCnt': '1879',
#   'decideCnt': '128282',
#   'examCnt': '84628',
#   'resutlNegCnt': '8951374',
#   'seq': '508',
#   'stateDt': '20210511',
#   'stateTime': '00:00',
#   'updateDt': '2021-05-27 09:53:30.741'},
#  {'accDefRate': '1.4136164637',
#   'accExamCnt': '9122059',
#   'accExamCompCnt': '9038661',
#   'careCnt': '8053',
#   'clearCnt': '117844',
#   'createDt': '2021-05-10 09:36:30.35',
#   'deathCnt': '1875',
#   'decideCnt': '127772',
#   'examCnt': '83398',
#   'resutlNegCnt': '8910889',
#   'seq': '507',
#   'stateDt': '20210510',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4107056010',
#   'accExamCnt': '9105771',
#   'accExamCompCnt': '9024491',
#   'careCnt': '8012',
#   'clearCnt': '117423',
#   'createDt': '2021-05-09 09:38:01.137',
#   'deathCnt': '1874',
#   'decideCnt': '127309',
#   'examCnt': '81280',
#   'resutlNegCnt': '8897182',
#   'seq': '506',
#   'stateDt': '20210509',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4065731673',
#   'accExamCnt': '9089166',
#   'accExamCompCnt': '9010907',
#   'careCnt': '7999',
#   'clearCnt': '116881',
#   'createDt': '2021-05-08 09:37:54.141',
#   'deathCnt': '1865',
#   'decideCnt': '126745',
#   'examCnt': '78259',
#   'resutlNegCnt': '8884162',
#   'seq': '505',
#   'stateDt': '20210508',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4047878518',
#   'accExamCnt': '9051354',
#   'accExamCompCnt': '8972458',
#   'careCnt': '8162',
#   'clearCnt': '116022',
#   'createDt': '2021-05-07 09:38:57.839',
#   'deathCnt': '1860',
#   'decideCnt': '126044',
#   'examCnt': '78896',
#   'resutlNegCnt': '8846414',
#   'seq': '504',
#   'stateDt': '20210507',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4049684926',
#   'accExamCnt': '9010992',
#   'accExamCompCnt': '8933937',
#   'careCnt': '8177',
#   'clearCnt': '115491',
#   'createDt': '2021-05-06 09:34:55.519',
#   'deathCnt': '1851',
#   'decideCnt': '125519',
#   'examCnt': '77055',
#   'resutlNegCnt': '8808418',
#   'seq': '503',
#   'stateDt': '20210506',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4015026684',
#   'accExamCnt': '8994069',
#   'accExamCompCnt': '8915074',
#   'careCnt': '8154',
#   'clearCnt': '114944',
#   'createDt': '2021-05-05 09:37:42.237',
#   'deathCnt': '1847',
#   'decideCnt': '124945',
#   'examCnt': '78995',
#   'resutlNegCnt': '8790129',
#   'seq': '502',
#   'stateDt': '20210505',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3995739863',
#   'accExamCnt': '8957155',
#   'accExamCompCnt': '8879059',
#   'careCnt': '8301',
#   'clearCnt': '114128',
#   'createDt': '2021-05-04 09:46:01.635',
#   'deathCnt': '1840',
#   'decideCnt': '124269',
#   'examCnt': '78096',
#   'resutlNegCnt': '8754790',
#   'seq': '501',
#   'stateDt': '20210504',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4018098628',
#   'accExamCnt': '8915326',
#   'accExamCompCnt': '8826304',
#   'careCnt': '8538',
#   'clearCnt': '113356',
#   'createDt': '2021-05-03 09:31:59.949',
#   'deathCnt': '1834',
#   'decideCnt': '123728',
#   'examCnt': '89022',
#   'resutlNegCnt': '8702576',
#   'seq': '500',
#   'stateDt': '20210503',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3986066364',
#   'accExamCnt': '8898234',
#   'accExamCompCnt': '8811627',
#   'careCnt': '8542',
#   'clearCnt': '112865',
#   'createDt': '2021-05-02 09:23:20.57',
#   'deathCnt': '1833',
#   'decideCnt': '123240',
#   'examCnt': '86607',
#   'resutlNegCnt': '8688387',
#   'seq': '499',
#   'stateDt': '20210502',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3938570903',
#   'accExamCnt': '8883388',
#   'accExamCompCnt': '8798176',
#   'careCnt': '8466',
#   'clearCnt': '112337',
#   'createDt': '2021-05-01 09:17:27.172',
#   'deathCnt': '1831',
#   'decideCnt': '122634',
#   'examCnt': '85212',
#   'resutlNegCnt': '8675542',
#   'seq': '498',
#   'stateDt': '20210501',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3918554433',
#   'accExamCnt': '8848292',
#   'accExamCompCnt': '8765781',
#   'careCnt': '8757',
#   'clearCnt': '111422',
#   'createDt': '2021-04-30 09:33:44.165',
#   'deathCnt': '1828',
#   'decideCnt': '122007',
#   'examCnt': '82511',
#   'resutlNegCnt': '8643774',
#   'seq': '497',
#   'stateDt': '20210430',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3907242112',
#   'accExamCnt': '8805774',
#   'accExamCompCnt': '8725382',
#   'careCnt': '8734',
#   'clearCnt': '110787',
#   'createDt': '2021-04-29 09:32:46.339',
#   'deathCnt': '1825',
#   'decideCnt': '121346',
#   'examCnt': '80392',
#   'resutlNegCnt': '8604036',
#   'seq': '496',
#   'stateDt': '20210429',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-30 09:39:29.337'},
#  {'accDefRate': '1.3886694305',
#   'accExamCnt': '8766491',
#   'accExamCompCnt': '8689325',
#   'careCnt': '8597',
#   'clearCnt': '110248',
#   'createDt': '2021-04-28 09:33:01.863',
#   'deathCnt': '1821',
#   'decideCnt': '120666',
#   'examCnt': '77166',
#   'resutlNegCnt': '8568659',
#   'seq': '495',
#   'stateDt': '20210428',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-30 09:39:12.945'},
#  {'accDefRate': '1.3868895227',
#   'accExamCnt': '8721609',
#   'accExamCompCnt': '8645101',
#   'careCnt': '8383',
#   'clearCnt': '109695',
#   'createDt': '2021-04-27 09:34:47.417',
#   'deathCnt': '1820',
#   'decideCnt': '119898',
#   'examCnt': '76508',
#   'resutlNegCnt': '8525203',
#   'seq': '494',
#   'stateDt': '20210427',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3890340008',
#   'accExamCnt': '8672978',
#   'accExamCompCnt': '8594894',
#   'careCnt': '8719',
#   'clearCnt': '108850',
#   'createDt': '2021-04-26 09:42:14.75',
#   'deathCnt': '1817',
#   'decideCnt': '119386',
#   'examCnt': '78084',
#   'resutlNegCnt': '8475508',
#   'seq': '493',
#   'stateDt': '20210426',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-27 09:37:24.371'},
#  {'accDefRate': '1.3860766953',
#   'accExamCnt': '8654791',
#   'accExamCompCnt': '8577231',
#   'careCnt': '8599',
#   'clearCnt': '108475',
#   'createDt': '2021-04-25 09:52:51.000',
#   'deathCnt': '1813',
#   'decideCnt': '118887',
#   'examCnt': '77560',
#   'resutlNegCnt': '8458344',
#   'seq': '492',
#   'stateDt': '20210425',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3822066912',
#   'accExamCnt': '8632923',
#   'accExamCompCnt': '8554654',
#   'careCnt': '8650',
#   'clearCnt': '107781',
#   'createDt': '2021-04-24 09:38:23.778',
#   'deathCnt': '1812',
#   'decideCnt': '118243',
#   'examCnt': '78269',
#   'resutlNegCnt': '8436411',
#   'seq': '491',
#   'stateDt': '20210424',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3796528397',
#   'accExamCnt': '8583530',
#   'accExamCompCnt': '8513591',
#   'careCnt': '8576',
#   'clearCnt': '107071',
#   'createDt': '2021-04-23 09:51:40.55',
#   'deathCnt': '1811',
#   'decideCnt': '117458',
#   'examCnt': '69939',
#   'resutlNegCnt': '8396133',
#   'seq': '490',
#   'stateDt': '20210423',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3772840512',
#   'accExamCnt': '8537505',
#   'accExamCompCnt': '8470366',
#   'careCnt': '8394',
#   'clearCnt': '106459',
#   'createDt': '2021-04-22 09:31:58.246',
#   'deathCnt': '1808',
#   'decideCnt': '116661',
#   'examCnt': '67139',
#   'resutlNegCnt': '8353705',
#   'seq': '489',
#   'stateDt': '20210422',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3750976675',
#   'accExamCnt': '8497594',
#   'accExamCompCnt': '8430383',
#   'careCnt': '8243',
#   'clearCnt': '105877',
#   'createDt': '2021-04-21 09:36:56.675',
#   'deathCnt': '1806',
#   'decideCnt': '115926',
#   'examCnt': '67211',
#   'resutlNegCnt': '8314457',
#   'seq': '488',
#   'stateDt': '20210421',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.4755317026',
#   'accExamCnt': '5061279',
#   'accExamCompCnt': '4901894',
#   'careCnt': '12827',
#   'clearCnt': '58253',
#   'createDt': '2021-01-17 15:27:58.692',
#   'deathCnt': '1249',
#   'decideCnt': '72329',
#   'examCnt': '159385',
#   'resutlNegCnt': '4829565',
#   'seq': '487',
#   'stateDt': '20210117',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 15:29:06.35'},
#  {'accDefRate': '1.3726760312',
#   'accExamCnt': '8458592',
#   'accExamCompCnt': '8392002',
#   'careCnt': '8166',
#   'clearCnt': '105227',
#   'createDt': '2021-04-20 09:34:02.801',
#   'deathCnt': '1802',
#   'decideCnt': '115195',
#   'examCnt': '66590',
#   'resutlNegCnt': '8276807',
#   'seq': '486',
#   'stateDt': '20210420',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3739837378',
#   'accExamCnt': '8414821',
#   'accExamCompCnt': '8344058',
#   'careCnt': '8371',
#   'clearCnt': '104474',
#   'createDt': '2021-04-19 09:39:21.483',
#   'deathCnt': '1801',
#   'decideCnt': '114646',
#   'examCnt': '70763',
#   'resutlNegCnt': '8229412',
#   'seq': '485',
#   'stateDt': '20210419',
#   'stateTime': '00:00',
#   'updateDt': 'null'},
#  {'accDefRate': '1.3709239987',
#   'accExamCnt': '8396066',
#   'accExamCompCnt': '8323875',
#   'careCnt': '8311',
#   'clearCnt': '104006',
#   'createDt': '2021-04-18 09:30:44.979',
#   'deathCnt': '1797',
#   'decideCnt': '114114',
#   'examCnt': '72191',
#   'resutlNegCnt': '8209761',
#   'seq': '484',
#   'stateDt': '20210418',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-19 09:39:27.906'},
#  {'accDefRate': '1.3656743037',
#   'accExamCnt': '8377778',
#   'accExamCompCnt': '8306739',
#   'careCnt': '8055',
#   'clearCnt': '103594',
#   'createDt': '2021-04-17 09:40:16.606',
#   'deathCnt': '1794',
#   'decideCnt': '113443',
#   'examCnt': '71039',
#   'resutlNegCnt': '8193296',
#   'seq': '483',
#   'stateDt': '20210417',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-18 09:35:59.415'},
#  {'accDefRate': '1.3650312837',
#   'accExamCnt': '8333331',
#   'accExamCompCnt': '8262448',
#   'careCnt': '7933',
#   'clearCnt': '103062',
#   'createDt': '2021-04-16 09:32:10.738',
#   'deathCnt': '1790',
#   'decideCnt': '112785',
#   'examCnt': '70883',
#   'resutlNegCnt': '8149663',
#   'seq': '482',
#   'stateDt': '20210416',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:35:13.573'},
#  {'accDefRate': '1.3637436290',
#   'accExamCnt': '8291121',
#   'accExamCompCnt': '8220900',
#   'careCnt': '7811',
#   'clearCnt': '102513',
#   'createDt': '2021-04-15 09:38:50.34',
#   'deathCnt': '1788',
#   'decideCnt': '112112',
#   'examCnt': '70221',
#   'resutlNegCnt': '8108788',
#   'seq': '481',
#   'stateDt': '20210415',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:35:43.42'},
#  {'accDefRate': '1.3635702742',
#   'accExamCnt': '8245383',
#   'accExamCompCnt': '8170756',
#   'careCnt': '7649',
#   'clearCnt': '101983',
#   'createDt': '2021-04-14 09:33:58.653',
#   'deathCnt': '1782',
#   'decideCnt': '111414',
#   'examCnt': '74627',
#   'resutlNegCnt': '8059342',
#   'seq': '480',
#   'stateDt': '20210414',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:35:54.244'},
#  {'accDefRate': '1.3639427573',
#   'accExamCnt': '8200514',
#   'accExamCompCnt': '8114930',
#   'careCnt': '7576',
#   'clearCnt': '101332',
#   'createDt': '2021-04-13 09:36:30.661',
#   'deathCnt': '1775',
#   'decideCnt': '110683',
#   'examCnt': '85584',
#   'resutlNegCnt': '8004247',
#   'seq': '479',
#   'stateDt': '20210413',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:36:13.585'},
#  {'accDefRate': '1.3669325463',
#   'accExamCnt': '8152778',
#   'accExamCompCnt': '8057530',
#   'careCnt': '7567',
#   'clearCnt': '100804',
#   'createDt': '2021-04-12 09:36:52.596',
#   'deathCnt': '1770',
#   'decideCnt': '110141',
#   'examCnt': '95248',
#   'resutlNegCnt': '7947389',
#   'seq': '478',
#   'stateDt': '20210412',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:36:31.34'},
#  {'accDefRate': '1.3630157591',
#   'accExamCnt': '8129527',
#   'accExamCompCnt': '8037618',
#   'careCnt': '7677',
#   'clearCnt': '100109',
#   'createDt': '2021-04-11 09:36:07.611',
#   'deathCnt': '1768',
#   'decideCnt': '109554',
#   'examCnt': '91909',
#   'resutlNegCnt': '7928064',
#   'seq': '477',
#   'stateDt': '20210411',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:36:51.706'},
#  {'accDefRate': '1.3589283551',
#   'accExamCnt': '8106625',
#   'accExamCompCnt': '8016611',
#   'careCnt': '7874',
#   'clearCnt': '99301',
#   'createDt': '2021-04-10 09:36:31.907',
#   'deathCnt': '1765',
#   'decideCnt': '108940',
#   'examCnt': '90014',
#   'resutlNegCnt': '7907671',
#   'seq': '476',
#   'stateDt': '20210410',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:37:10.346'},
#  {'accDefRate': '1.3571562435',
#   'accExamCnt': '8059107',
#   'accExamCompCnt': '7977195',
#   'careCnt': '7713',
#   'clearCnt': '98786',
#   'createDt': '2021-04-09 09:33:53.3',
#   'deathCnt': '1764',
#   'decideCnt': '108263',
#   'examCnt': '81912',
#   'resutlNegCnt': '7868932',
#   'seq': '475',
#   'stateDt': '20210409',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:37:51.855'},
#  {'accDefRate': '1.3560157697',
#   'accExamCnt': '8012415',
#   'accExamCompCnt': '7934421',
#   'careCnt': '7474',
#   'clearCnt': '98360',
#   'createDt': '2021-04-08 09:30:58.826',
#   'deathCnt': '1758',
#   'decideCnt': '107592',
#   'examCnt': '77994',
#   'resutlNegCnt': '7826829',
#   'seq': '474',
#   'stateDt': '20210408',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:38:13.56'},
#  {'accDefRate': '1.3545174256',
#   'accExamCnt': '7966161',
#   'accExamCompCnt': '7891519',
#   'careCnt': '7208',
#   'clearCnt': '97928',
#   'createDt': '2021-04-07 09:37:24.979',
#   'deathCnt': '1756',
#   'decideCnt': '106892',
#   'examCnt': '74642',
#   'resutlNegCnt': '7784627',
#   'seq': '473',
#   'stateDt': '20210407',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:38:33.513'},
#  {'accDefRate': '1.3545301282',
#   'accExamCnt': '7921284',
#   'accExamCompCnt': '7842129',
#   'careCnt': '7109',
#   'clearCnt': '97363',
#   'createDt': '2021-04-06 09:31:57.498',
#   'deathCnt': '1752',
#   'decideCnt': '106224',
#   'examCnt': '79155',
#   'resutlNegCnt': '7735905',
#   'seq': '472',
#   'stateDt': '20210406',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:39:01.36'},
#  {'accDefRate': '1.3577642823',
#   'accExamCnt': '7868815',
#   'accExamCompCnt': '7788318',
#   'careCnt': '7099',
#   'clearCnt': '96900',
#   'createDt': '2021-04-05 09:44:27.235',
#   'deathCnt': '1748',
#   'decideCnt': '105747',
#   'examCnt': '80497',
#   'resutlNegCnt': '7682571',
#   'seq': '471',
#   'stateDt': '20210405',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:39:30.302'},
#  {'accDefRate': '1.3549222354',
#   'accExamCnt': '7849470',
#   'accExamCompCnt': '7769671',
#   'careCnt': '6940',
#   'clearCnt': '96589',
#   'createDt': '2021-04-04 09:45:05.147',
#   'deathCnt': '1744',
#   'decideCnt': '105273',
#   'examCnt': '79799',
#   'resutlNegCnt': '7664398',
#   'seq': '470',
#   'stateDt': '20210404',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:40:12.582'},
#  {'accDefRate': '1.3506169731',
#   'accExamCnt': '7829596',
#   'accExamCompCnt': '7754308',
#   'careCnt': '6795',
#   'clearCnt': '96196',
#   'createDt': '2021-04-03 09:34:03.806',
#   'deathCnt': '1740',
#   'decideCnt': '104731',
#   'examCnt': '75288',
#   'resutlNegCnt': '7649577',
#   'seq': '469',
#   'stateDt': '20210403',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:40:25.997'},
#  {'accDefRate': '1.3500160284',
#   'accExamCnt': '7788290',
#   'accExamCompCnt': '7717538',
#   'careCnt': '6590',
#   'clearCnt': '95861',
#   'createDt': '2021-04-02 09:54:00.108',
#   'deathCnt': '1737',
#   'decideCnt': '104188',
#   'examCnt': '70752',
#   'resutlNegCnt': '7613350',
#   'seq': '468',
#   'stateDt': '20210402',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:40:42.759'},
#  {'accDefRate': '1.3496016740',
#   'accExamCnt': '7747295',
#   'accExamCompCnt': '7678636',
#   'careCnt': '6457',
#   'clearCnt': '95439',
#   'createDt': '2021-04-01 09:32:19.52',
#   'deathCnt': '1735',
#   'decideCnt': '103631',
#   'examCnt': '68659',
#   'resutlNegCnt': '7575005',
#   'seq': '467',
#   'stateDt': '20210401',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:41:23.051'},
#  {'accDefRate': '1.3498348063',
#   'accExamCnt': '7707792',
#   'accExamCompCnt': '7636490',
#   'careCnt': '6319',
#   'clearCnt': '95030',
#   'createDt': '2021-03-31 09:32:59.933',
#   'deathCnt': '1731',
#   'decideCnt': '103080',
#   'examCnt': '71302',
#   'resutlNegCnt': '7533410',
#   'seq': '466',
#   'stateDt': '20210331',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:41:41.712'},
#  {'accDefRate': '1.3522258784',
#   'accExamCnt': '7663991',
#   'accExamCompCnt': '7585567',
#   'careCnt': '6282',
#   'clearCnt': '94563',
#   'createDt': '2021-03-30 09:39:54.626',
#   'deathCnt': '1729',
#   'decideCnt': '102574',
#   'examCnt': '78424',
#   'resutlNegCnt': '7482993',
#   'seq': '465',
#   'stateDt': '20210330',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:42:04.778'},
#  {'accDefRate': '1.3549404905',
#   'accExamCnt': '7616317',
#   'accExamCompCnt': '7537379',
#   'careCnt': '6277',
#   'clearCnt': '94124',
#   'createDt': '2021-03-29 09:41:57.983',
#   'deathCnt': '1726',
#   'decideCnt': '102127',
#   'examCnt': '78938',
#   'resutlNegCnt': '7435252',
#   'seq': '463',
#   'stateDt': '20210329',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:42:25.82'},
#  {'accDefRate': '1.3535357754',
#   'accExamCnt': '7595584',
#   'accExamCompCnt': '7516979',
#   'careCnt': '6168',
#   'clearCnt': '93855',
#   'createDt': '2021-03-28 11:17:23.373',
#   'deathCnt': '1722',
#   'decideCnt': '101745',
#   'examCnt': '78605',
#   'resutlNegCnt': '7415234',
#   'seq': '462',
#   'stateDt': '20210328',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:42:38.562'},
#  {'accDefRate': '1.3506447984',
#   'accExamCnt': '7572556',
#   'accExamCompCnt': '7497382',
#   'careCnt': '6067',
#   'clearCnt': '93475',
#   'createDt': '2021-03-27 09:53:35.032',
#   'deathCnt': '1721',
#   'decideCnt': '101263',
#   'examCnt': '75174',
#   'resutlNegCnt': '7396119',
#   'seq': '461',
#   'stateDt': '20210327',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:42:54.126'},
#  {'accDefRate': '1.3520966636',
#   'accExamCnt': '7529391',
#   'accExamCompCnt': '7451982',
#   'careCnt': '6412',
#   'clearCnt': '92630',
#   'createDt': '2021-03-26 09:33:28.3',
#   'deathCnt': '1716',
#   'decideCnt': '100758',
#   'examCnt': '77409',
#   'resutlNegCnt': '7351224',
#   'seq': '460',
#   'stateDt': '20210326',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:43:22.594'},
#  {'accDefRate': '1.3551936113',
#   'accExamCnt': '7485852',
#   'accExamCompCnt': '7398869',
#   'careCnt': '6492',
#   'clearCnt': '92068',
#   'createDt': '2021-03-25 09:34:48.91',
#   'deathCnt': '1709',
#   'decideCnt': '100269',
#   'examCnt': '86983',
#   'resutlNegCnt': '7298600',
#   'seq': '459',
#   'stateDt': '20210325',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:43:42.787'},
#  {'accDefRate': '1.3589311485',
#   'accExamCnt': '7441203',
#   'accExamCompCnt': '7346877',
#   'careCnt': '6572',
#   'clearCnt': '91560',
#   'createDt': '2021-03-24 09:35:12.391',
#   'deathCnt': '1707',
#   'decideCnt': '99839',
#   'examCnt': '94326',
#   'resutlNegCnt': '7247038',
#   'seq': '458',
#   'stateDt': '20210324',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:43:58.157'},
#  {'accDefRate': '1.3616438070',
#   'accExamCnt': '7400980',
#   'accExamCompCnt': '7300808',
#   'careCnt': '6628',
#   'clearCnt': '91079',
#   'createDt': '2021-03-23 09:32:10.986',
#   'deathCnt': '1704',
#   'decideCnt': '99411',
#   'examCnt': '100172',
#   'resutlNegCnt': '7201397',
#   'seq': '457',
#   'stateDt': '20210323',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:44:18.502'},
#  {'accDefRate': '1.3658821352',
#   'accExamCnt': '7355954',
#   'accExamCompCnt': '7252822',
#   'careCnt': '6757',
#   'clearCnt': '90611',
#   'createDt': '2021-03-22 10:04:58.004',
#   'deathCnt': '1697',
#   'decideCnt': '99065',
#   'examCnt': '103132',
#   'resutlNegCnt': '7153757',
#   'seq': '456',
#   'stateDt': '20210322',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:44:34.623'},
#  {'accDefRate': '1.3636254938',
#   'accExamCnt': '7332699',
#   'accExamCompCnt': '7234391',
#   'careCnt': '6626',
#   'clearCnt': '90328',
#   'createDt': '2021-03-21 09:53:34.815',
#   'deathCnt': '1696',
#   'decideCnt': '98650',
#   'examCnt': '98308',
#   'resutlNegCnt': '7135741',
#   'seq': '455',
#   'stateDt': '20210321',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:45:11.413'},
#  {'accDefRate': '1.3607972486',
#   'accExamCnt': '7308935',
#   'accExamCompCnt': '7215917',
#   'careCnt': '6552',
#   'clearCnt': '89949',
#   'createDt': '2021-03-20 09:31:53.146',
#   'deathCnt': '1693',
#   'decideCnt': '98194',
#   'examCnt': '93018',
#   'resutlNegCnt': '7117723',
#   'seq': '454',
#   'stateDt': '20210320',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:45:35.163'},
#  {'accDefRate': '1.3620256974',
#   'accExamCnt': '7264931',
#   'accExamCompCnt': '7176590',
#   'careCnt': '6534',
#   'clearCnt': '89523',
#   'createDt': '2021-03-19 09:32:03.884',
#   'deathCnt': '1690',
#   'decideCnt': '97747',
#   'examCnt': '88341',
#   'resutlNegCnt': '7078843',
#   'seq': '453',
#   'stateDt': '20210319',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:45:53.021'},
#  {'accDefRate': '1.3647468455',
#   'accExamCnt': '7218077',
#   'accExamCompCnt': '7128355',
#   'careCnt': '6418',
#   'clearCnt': '89178',
#   'createDt': '2021-03-18 09:38:40.962',
#   'deathCnt': '1688',
#   'decideCnt': '97284',
#   'examCnt': '89722',
#   'resutlNegCnt': '7031071',
#   'seq': '452',
#   'stateDt': '20210318',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:46:21.32'},
#  {'accDefRate': '1.3662313887',
#   'accExamCnt': '7171500',
#   'accExamCompCnt': '7088038',
#   'careCnt': '6339',
#   'clearCnt': '88814',
#   'createDt': '2021-03-17 09:31:37.789',
#   'deathCnt': '1686',
#   'decideCnt': '96839',
#   'examCnt': '83462',
#   'resutlNegCnt': '6991199',
#   'seq': '451',
#   'stateDt': '20210317',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:46:39.82'},
#  {'accDefRate': '1.3673337899',
#   'accExamCnt': '7126067',
#   'accExamCompCnt': '7048023',
#   'careCnt': '6437',
#   'clearCnt': '88255',
#   'createDt': '2021-03-16 09:36:13.502',
#   'deathCnt': '1678',
#   'decideCnt': '96370',
#   'examCnt': '78044',
#   'resutlNegCnt': '6951653',
#   'seq': '450',
#   'stateDt': '20210316',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:46:59.298'},
#  {'accDefRate': '1.3689198014',
#   'accExamCnt': '7084930',
#   'accExamCompCnt': '7013340',
#   'careCnt': '6578',
#   'clearCnt': '87754',
#   'createDt': '2021-03-15 09:51:09.37',
#   'deathCnt': '1675',
#   'decideCnt': '96007',
#   'examCnt': '71590',
#   'resutlNegCnt': '6917333',
#   'seq': '449',
#   'stateDt': '20210315',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:47:28.958'},
#  {'accDefRate': '1.3667877215',
#   'accExamCnt': '7066394',
#   'accExamCompCnt': '6996551',
#   'careCnt': '6551',
#   'clearCnt': '87408',
#   'createDt': '2021-03-14 09:42:57.64',
#   'deathCnt': '1669',
#   'decideCnt': '95628',
#   'examCnt': '69843',
#   'resutlNegCnt': '6900923',
#   'seq': '448',
#   'stateDt': '20210314',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:47:44.94'},
#  {'accDefRate': '1.3636674313',
#   'accExamCnt': '7046775',
#   'accExamCompCnt': '6978901',
#   'careCnt': '6877',
#   'clearCnt': '86625',
#   'createDt': '2021-03-13 09:36:41.886',
#   'deathCnt': '1667',
#   'decideCnt': '95169',
#   'examCnt': '67874',
#   'resutlNegCnt': '6883732',
#   'seq': '447',
#   'stateDt': '20210313',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:48:06.227'},
#  {'accDefRate': '1.3634807664',
#   'accExamCnt': '7012657',
#   'accExamCompCnt': '6943919',
#   'careCnt': '7274',
#   'clearCnt': '85743',
#   'createDt': '2021-03-12 09:49:58.077',
#   'deathCnt': '1662',
#   'decideCnt': '94679',
#   'examCnt': '68738',
#   'resutlNegCnt': '6849240',
#   'seq': '446',
#   'stateDt': '20210312',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:48:36.524'},
#  {'accDefRate': '1.3633620071',
#   'accExamCnt': '6976978',
#   'accExamCompCnt': '6908730',
#   'careCnt': '7864',
#   'clearCnt': '84675',
#   'createDt': '2021-03-11 09:39:02.159',
#   'deathCnt': '1652',
#   'decideCnt': '94191',
#   'examCnt': '68248',
#   'resutlNegCnt': '6814539',
#   'seq': '445',
#   'stateDt': '20210311',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:48:58.191'},
#  {'accDefRate': '1.3645577504',
#   'accExamCnt': '6938877',
#   'accExamCompCnt': '6868599',
#   'careCnt': '7766',
#   'clearCnt': '84312',
#   'createDt': '2021-03-10 09:45:29.181',
#   'deathCnt': '1648',
#   'decideCnt': '93726',
#   'examCnt': '70278',
#   'resutlNegCnt': '6774873',
#   'seq': '444',
#   'stateDt': '20210310',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:50:56.417'},
#  {'accDefRate': '1.3648931953',
#   'accExamCnt': '6902977',
#   'accExamCompCnt': '6832476',
#   'careCnt': '7711',
#   'clearCnt': '83900',
#   'createDt': '2021-03-09 09:52:46.909',
#   'deathCnt': '1645',
#   'decideCnt': '93256',
#   'examCnt': '70501',
#   'resutlNegCnt': '6739220',
#   'seq': '443',
#   'stateDt': '20210309',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:51:28.616'},
#  {'accDefRate': '1.3659762557',
#   'accExamCnt': '6861802',
#   'accExamCompCnt': '6794408',
#   'careCnt': '7694',
#   'clearCnt': '83474',
#   'createDt': '2021-03-08 09:31:46.646',
#   'deathCnt': '1642',
#   'decideCnt': '92810',
#   'examCnt': '67394',
#   'resutlNegCnt': '6701598',
#   'seq': '442',
#   'stateDt': '20210308',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:51:41.422'},
#  {'accDefRate': '1.3644352882',
#   'accExamCnt': '6843119',
#   'accExamCompCnt': '6776723',
#   'careCnt': '7610',
#   'clearCnt': '83220',
#   'createDt': '2021-03-07 09:52:34.246',
#   'deathCnt': '1634',
#   'decideCnt': '92464',
#   'examCnt': '66396',
#   'resutlNegCnt': '6684259',
#   'seq': '441',
#   'stateDt': '20210307',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:51:55.518'},
#  {'accDefRate': '1.3623087379',
#   'accExamCnt': '6821936',
#   'accExamCompCnt': '6756765',
#   'careCnt': '7503',
#   'clearCnt': '82913',
#   'createDt': '2021-03-06 09:40:17.621',
#   'deathCnt': '1632',
#   'decideCnt': '92048',
#   'examCnt': '65171',
#   'resutlNegCnt': '6664717',
#   'seq': '440',
#   'stateDt': '20210306',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:56:41.076'},
#  {'accDefRate': '1.3624677096',
#   'accExamCnt': '6789004',
#   'accExamCompCnt': '6725297',
#   'careCnt': '7443',
#   'clearCnt': '82560',
#   'createDt': '2021-03-05 09:41:54.92',
#   'deathCnt': '1627',
#   'decideCnt': '91630',
#   'examCnt': '63707',
#   'resutlNegCnt': '6633667',
#   'seq': '439',
#   'stateDt': '20210305',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:57:05.073'},
#  {'accDefRate': '1.3633393924',
#   'accExamCnt': '6751893',
#   'accExamCompCnt': '6691804',
#   'careCnt': '7451',
#   'clearCnt': '82162',
#   'createDt': '2021-03-04 09:33:23.999',
#   'deathCnt': '1619',
#   'decideCnt': '91232',
#   'examCnt': '60089',
#   'resutlNegCnt': '6600572',
#   'seq': '438',
#   'stateDt': '20210304',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:57:22.272'},
#  {'accDefRate': '1.3654662799',
#   'accExamCnt': '6716196',
#   'accExamCompCnt': '6650329',
#   'careCnt': '7496',
#   'clearCnt': '81700',
#   'createDt': '2021-03-03 09:33:02.813',
#   'deathCnt': '1612',
#   'decideCnt': '90808',
#   'examCnt': '65867',
#   'resutlNegCnt': '6559521',
#   'seq': '437',
#   'stateDt': '20210303',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:57:38.163'},
#  {'accDefRate': '1.3673828261',
#   'accExamCnt': '6681969',
#   'accExamCompCnt': '6608537',
#   'careCnt': '7420',
#   'clearCnt': '81338',
#   'createDt': '2021-03-02 09:32:41.95',
#   'deathCnt': '1606',
#   'decideCnt': '90364',
#   'examCnt': '73432',
#   'resutlNegCnt': '6518173',
#   'seq': '436',
#   'stateDt': '20210302',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:57:59.417'},
#  {'accDefRate': '1.3655942458',
#   'accExamCnt': '6665747',
#   'accExamCompCnt': '6592002',
#   'careCnt': '7345',
#   'clearCnt': '81070',
#   'createDt': '2021-03-01 09:48:21.402',
#   'deathCnt': '1605',
#   'decideCnt': '90020',
#   'examCnt': '73745',
#   'resutlNegCnt': '6501982',
#   'seq': '435',
#   'stateDt': '20210301',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:58:56.038'},
#  {'accDefRate': '1.3634966705',
#   'accExamCnt': '6648996',
#   'accExamCompCnt': '6576107',
#   'careCnt': '7365',
#   'clearCnt': '80697',
#   'createDt': '2021-02-28 10:24:54.713',
#   'deathCnt': '1603',
#   'decideCnt': '89665',
#   'examCnt': '72889',
#   'resutlNegCnt': '6486442',
#   'seq': '434',
#   'stateDt': '20210228',
#   'stateTime': '00:00',
#   'updateDt': '2021-04-20 14:59:08.938'},
# ...
#   'decideCnt': '9241',
#   'examCnt': '14369',
#   'resutlNegCnt': '341332',
#   'seq': '86',
#   'stateDt': '20200326',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-26 10:40:50.50'},
#  {'accDefRate': '2.6590574416',
#   'accExamCnt': '357896',
#   'accExamCompCnt': '343618',
#   'careCnt': '5410',
#   'clearCnt': '3730',
#   'createDt': '2020-03-25 10:12:04.04',
#   'deathCnt': '126',
#   'decideCnt': '9137',
#   'examCnt': '14278',
#   'resutlNegCnt': '334481',
#   'seq': '85',
#   'stateDt': '20200325',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-25 10:12:04.04'},
#  {'accDefRate': '2.7126570651',
#   'accExamCnt': '348582',
#   'accExamCompCnt': '333142',
#   'careCnt': '5684',
#   'clearCnt': '3507',
#   'createDt': '2020-03-24 10:20:57.57',
#   'deathCnt': '120',
#   'decideCnt': '9037',
#   'examCnt': '15440',
#   'resutlNegCnt': '324105',
#   'seq': '84',
#   'stateDt': '20200324',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-24 10:20:57.57'},
#  {'accDefRate': '2.7622623363',
#   'accExamCnt': '338036',
#   'accExamCompCnt': '324408',
#   'careCnt': '5884',
#   'clearCnt': '3166',
#   'createDt': '2020-03-23 10:27:32.32',
#   'deathCnt': '111',
#   'decideCnt': '8961',
#   'examCnt': '13628',
#   'resutlNegCnt': '315447',
#   'seq': '82',
#   'stateDt': '20200323',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-23 10:27:32.32'},
#  {'accDefRate': '2.8045013239',
#   'accExamCnt': '331780',
#   'accExamCompCnt': '317240',
#   'careCnt': '6085',
#   'clearCnt': '2909',
#   'createDt': '2020-03-22 10:07:28.28',
#   'deathCnt': '104',
#   'decideCnt': '8897',
#   'examCnt': '14540',
#   'resutlNegCnt': '308343',
#   'seq': '81',
#   'stateDt': '20200322',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-22 10:07:28.28'},
#  {'accDefRate': '2.8219560302',
#   'accExamCnt': '327509',
#   'accExamCompCnt': '311805',
#   'careCnt': '6325',
#   'clearCnt': '2612',
#   'createDt': '2020-03-21 10:02:58.58',
#   'deathCnt': '102',
#   'decideCnt': '8799',
#   'examCnt': '15704',
#   'resutlNegCnt': '303006',
#   'seq': '80',
#   'stateDt': '20200321',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-21 10:02:58.58'},
#  {'accDefRate': '2.8730918280',
#   'accExamCnt': '316664',
#   'accExamCompCnt': '301139',
#   'careCnt': '6527',
#   'clearCnt': '2233',
#   'createDt': '2020-03-20 10:15:59.59',
#   'deathCnt': '94',
#   'decideCnt': '8652',
#   'examCnt': '15525',
#   'resutlNegCnt': '292487',
#   'seq': '79',
#   'stateDt': '20200320',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-20 10:15:59.59'},
#  {'accDefRate': '2.9420857378',
#   'accExamCnt': '307024',
#   'accExamCompCnt': '291120',
#   'careCnt': '6789',
#   'clearCnt': '1947',
#   'createDt': '2020-03-19 10:07:57.57',
#   'deathCnt': '91',
#   'decideCnt': '8565',
#   'examCnt': '15904',
#   'resutlNegCnt': '282555',
#   'seq': '78',
#   'stateDt': '20200319',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-19 10:07:57.57'},
#  {'accDefRate': '3.0121625056',
#   'accExamCnt': '295647',
#   'accExamCompCnt': '279301',
#   'careCnt': '6838',
#   'clearCnt': '1540',
#   'createDt': '2020-03-18 10:26:15.15',
#   'deathCnt': '84',
#   'decideCnt': '8413',
#   'examCnt': '16346',
#   'resutlNegCnt': '270888',
#   'seq': '77',
#   'stateDt': '20200318',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-18 10:26:15.15'},
#  {'accDefRate': '3.0880579010',
#   'accExamCnt': '286716',
#   'accExamCompCnt': '269425',
#   'careCnt': '7024',
#   'clearCnt': '1401',
#   'createDt': '2020-03-17 10:29:38.38',
#   'deathCnt': '81',
#   'decideCnt': '8320',
#   'examCnt': '17291',
#   'resutlNegCnt': '261105',
#   'seq': '76',
#   'stateDt': '20200317',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-17 10:29:38.38'},
#  {'accDefRate': '3.1733922083',
#   'accExamCnt': '274504',
#   'accExamCompCnt': '259533',
#   'careCnt': '7253',
#   'clearCnt': '1137',
#   'createDt': '2020-03-16 10:12:33.33',
#   'deathCnt': '75',
#   'decideCnt': '8236',
#   'examCnt': '14971',
#   'resutlNegCnt': '251297',
#   'seq': '75',
#   'stateDt': '20200316',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-16 10:12:33.33'},
#  {'accDefRate': '3.2396602365',
#   'accExamCnt': '268212',
#   'accExamCompCnt': '251940',
#   'careCnt': '7300',
#   'clearCnt': '834',
#   'createDt': '2020-03-15 10:01:22.22',
#   'deathCnt': '75',
#   'decideCnt': '8162',
#   'examCnt': '16272',
#   'resutlNegCnt': '243778',
#   'seq': '74',
#   'stateDt': '20200315',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-15 10:01:22.22'},
#  {'accDefRate': '3.3180003364',
#   'accExamCnt': '261335',
#   'accExamCompCnt': '243701',
#   'careCnt': '7402',
#   'clearCnt': '714',
#   'createDt': '2020-03-14 10:29:11.11',
#   'deathCnt': '72',
#   'decideCnt': '8086',
#   'examCnt': '17634',
#   'resutlNegCnt': '235615',
#   'seq': '73',
#   'stateDt': '20200314',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-14 10:29:11.11'},
#  {'accDefRate': '3.4584993086',
#   'accExamCnt': '248647',
#   'accExamCompCnt': '230707',
#   'careCnt': '7470',
#   'clearCnt': '510',
#   'createDt': '2020-03-13 10:07:22.22',
#   'deathCnt': '67',
#   'decideCnt': '7979',
#   'examCnt': '17940',
#   'resutlNegCnt': '222728',
#   'seq': '72',
#   'stateDt': '20200313',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-13 10:07:22.22'},
#  {'accDefRate': '3.6217442732',
#   'accExamCnt': '234998',
#   'accExamCompCnt': '217271',
#   'careCnt': '7407',
#   'clearCnt': '333',
#   'createDt': '2020-03-12 10:37:03.03',
#   'deathCnt': '66',
#   'decideCnt': '7869',
#   'examCnt': '17727',
#   'resutlNegCnt': '209402',
#   'seq': '71',
#   'stateDt': '20200312',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-12 10:37:03.03'},
#  {'accDefRate': '3.8041745358',
#   'accExamCnt': '222395',
#   'accExamCompCnt': '203855',
#   'careCnt': '7212',
#   'clearCnt': '288',
#   'createDt': '2020-03-11 10:17:19.19',
#   'deathCnt': '60',
#   'decideCnt': '7755',
#   'examCnt': '18540',
#   'resutlNegCnt': '196100',
#   'seq': '70',
#   'stateDt': '20200311',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-11 10:17:19.19'},
#  {'accDefRate': '3.9193080566',
#   'accExamCnt': '210144',
#   'accExamCompCnt': '191692',
#   'careCnt': '7165',
#   'clearCnt': '247',
#   'createDt': '2020-03-10 10:20:27.27',
#   'deathCnt': '54',
#   'decideCnt': '7513',
#   'examCnt': '18452',
#   'resutlNegCnt': '184179',
#   'seq': '69',
#   'stateDt': '20200310',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-10 10:20:27.27'},
#  {'accDefRate': '4.1203393614',
#   'accExamCnt': '196618',
#   'accExamCompCnt': '179160',
#   'careCnt': '6954',
#   'clearCnt': '166',
#   'createDt': '2020-03-09 10:47:15.15',
#   'deathCnt': '51',
#   'decideCnt': '7382',
#   'examCnt': '17458',
#   'resutlNegCnt': '171778',
#   'seq': '68',
#   'stateDt': '20200309',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-09 10:47:15.15'},
#  {'accDefRate': '4.2177578602',
#   'accExamCnt': '188518',
#   'accExamCompCnt': '169142',
#   'careCnt': '6605',
#   'clearCnt': '130',
#   'createDt': '2020-03-08 11:16:27.27',
#   'deathCnt': '50',
#   'decideCnt': '7134',
#   'examCnt': '19376',
#   'resutlNegCnt': '162008',
#   'seq': '67',
#   'stateDt': '20200308',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-08 11:16:27.27'},
#  {'accDefRate': '4.2675428362',
#   'accExamCnt': '178189',
#   'accExamCompCnt': '158569',
#   'careCnt': '6134',
#   'clearCnt': '118',
#   'createDt': '2020-03-07 11:00:45.45',
#   'deathCnt': '44',
#   'decideCnt': '6767',
#   'examCnt': '19620',
#   'resutlNegCnt': '151802',
#   'seq': '66',
#   'stateDt': '20200307',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-07 11:00:45.45'},
#  {'accDefRate': '4.3972345844',
#   'accExamCnt': '164740',
#   'accExamCompCnt': '142908',
#   'careCnt': '5643',
#   'clearCnt': '108',
#   'createDt': '2020-03-06 12:55:44.44',
#   'deathCnt': '42',
#   'decideCnt': '6284',
#   'examCnt': '21832',
#   'resutlNegCnt': '136624',
#   'seq': '65',
#   'stateDt': '20200306',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-06 12:55:44.44'},
#  {'accDefRate': '4.6227481540',
#   'accExamCnt': '146541',
#   'accExamCompCnt': '124731',
#   'careCnt': '5255',
#   'clearCnt': '88',
#   'createDt': '2020-03-05 10:15:12.12',
#   'deathCnt': '35',
#   'decideCnt': '5766',
#   'examCnt': '21810',
#   'resutlNegCnt': '118965',
#   'seq': '64',
#   'stateDt': '20200305',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-05 10:15:12.12'},
#  {'accDefRate': '4.9199855946',
#   'accExamCnt': '136707',
#   'accExamCompCnt': '108293',
#   'careCnt': '4750',
#   'clearCnt': '41',
#   'createDt': '2020-03-04 10:21:44.44',
#   'deathCnt': '32',
#   'decideCnt': '5328',
#   'examCnt': '28414',
#   'resutlNegCnt': '102965',
#   'seq': '63',
#   'stateDt': '20200304',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-04 10:21:44.44'},
#  {'accDefRate': '5.3291397182',
#   'accExamCnt': '125851',
#   'accExamCompCnt': '90296',
#   'careCnt': '4159',
#   'clearCnt': '34',
#   'createDt': '2020-03-03 10:46:53.53',
#   'deathCnt': '28',
#   'decideCnt': '4812',
#   'examCnt': '35555',
#   'resutlNegCnt': '85484',
#   'seq': '62',
#   'stateDt': '20200303',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-03 10:46:53.53'},
#  {'accDefRate': '5.5573147561',
#   'accExamCnt': '109591',
#   'accExamCompCnt': '75792',
#   'clearCnt': '31',
#   'createDt': '2020-03-02 10:52:38.38',
#   'deathCnt': '22',
#   'decideCnt': '4212',
#   'examCnt': '33799',
#   'resutlNegCnt': '71580',
#   'seq': '61',
#   'stateDt': '20200302',
#   'stateTime': '00:00',
#   'updateDt': '2020-03-02 10:52:38.38'},
#  {'clearCnt': '30',
#   'createDt': '2020-03-01 17:41:45.45',
#   'deathCnt': '18',
#   'decideCnt': '3736',
#   'examCnt': '33360',
#   'seq': '60',
#   'stateDt': '20200301',
#   'stateTime': '16:00',
#   'updateDt': '2020-03-01 17:41:45.45'},
#  {'clearCnt': '28',
#   'createDt': '2020-02-29 17:16:20.20',
#   'deathCnt': '17',
#   'decideCnt': '3150',
#   'examCnt': '35182',
#   'seq': '58',
#   'stateDt': '20200229',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-29 17:16:20.20'},
#  {'clearCnt': '27',
#   'createDt': '2020-02-28 17:01:59.59',
#   'deathCnt': '13',
#   'decideCnt': '2337',
#   'examCnt': '30237',
#   'seq': '56',
#   'stateDt': '20200228',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-28 17:01:59.59'},
#  {'clearCnt': '26',
#   'createDt': '2020-02-27 17:32:06.06',
#   'deathCnt': '13',
#   'decideCnt': '1766',
#   'examCnt': '25568',
#   'seq': '54',
#   'stateDt': '20200227',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-27 17:32:06.06'},
#  {'clearCnt': '24',
#   'createDt': '2020-02-26 17:00:43.43',
#   'deathCnt': '12',
#   'decideCnt': '1261',
#   'examCnt': '20716',
#   'seq': '52',
#   'stateDt': '20200226',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-26 17:00:43.43'},
#  {'clearCnt': '22',
#   'createDt': '2020-02-25 17:02:03.03',
#   'deathCnt': '10',
#   'decideCnt': '977',
#   'examCnt': '13880',
#   'seq': '50',
#   'stateDt': '20200225',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-25 17:02:03.03'},
#  {'clearCnt': '22',
#   'createDt': '2020-02-24 17:03:50.50',
#   'deathCnt': '7',
#   'decideCnt': '833',
#   'examCnt': '11631',
#   'seq': '48',
#   'stateDt': '20200224',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-24 17:03:50.50'},
#  {'clearCnt': '18',
#   'createDt': '2020-02-23 17:05:12.12',
#   'deathCnt': '5',
#   'decideCnt': '602',
#   'examCnt': '8057',
#   'seq': '46',
#   'stateDt': '20200223',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-23 17:05:12.12'},
#  {'clearCnt': '18',
#   'createDt': '2020-02-22 17:00:28.28',
#   'deathCnt': '2',
#   'decideCnt': '433',
#   'examCnt': '6037',
#   'seq': '44',
#   'stateDt': '20200222',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-22 17:00:28.28'},
#  {'clearCnt': '17',
#   'createDt': '2020-02-21 17:13:21.21',
#   'deathCnt': '1',
#   'decideCnt': '204',
#   'examCnt': '3180',
#   'seq': '42',
#   'stateDt': '20200221',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-21 17:13:21.21'},
#  {'clearCnt': '16',
#   'createDt': '2020-02-20 17:12:33.33',
#   'deathCnt': '1',
#   'decideCnt': '104',
#   'examCnt': '1860',
#   'seq': '39',
#   'stateDt': '20200220',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-20 17:12:33.33'},
#  {'clearCnt': '16',
#   'createDt': '2020-02-19 17:00:13.13',
#   'deathCnt': '0',
#   'decideCnt': '51',
#   'examCnt': '1149',
#   'seq': '37',
#   'stateDt': '20200219',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-19 17:00:13.13'},
#  {'clearCnt': '12',
#   'createDt': '2020-02-18 16:42:00.00',
#   'deathCnt': '0',
#   'decideCnt': '31',
#   'examCnt': '818',
#   'seq': '35',
#   'stateDt': '20200218',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-18 16:42:00.00'},
#  {'clearCnt': '10',
#   'createDt': '2020-02-17 16:50:47.47',
#   'deathCnt': '0',
#   'decideCnt': '30',
#   'examCnt': '708',
#   'seq': '32',
#   'stateDt': '20200217',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-17 16:50:47.47'},
#  {'clearCnt': '9',
#   'createDt': '2020-02-16 16:57:02.02',
#   'deathCnt': '0',
#   'decideCnt': '29',
#   'examCnt': '485',
#   'seq': '30',
#   'stateDt': '20200216',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-16 16:57:02.02'},
#  {'clearCnt': '9',
#   'createDt': '2020-02-15 17:00:21.21',
#   'deathCnt': '0',
#   'decideCnt': '28',
#   'examCnt': '558',
#   'seq': '28',
#   'stateDt': '20200215',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-15 17:00:21.21'},
#  {'clearCnt': '7',
#   'createDt': '2020-02-14 17:16:19.19',
#   'deathCnt': '0',
#   'decideCnt': '28',
#   'examCnt': '535',
#   'seq': '26',
#   'stateDt': '20200214',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-14 17:16:19.19'},
#  {'clearCnt': '7',
#   'createDt': '2020-02-13 17:09:07.07',
#   'deathCnt': '0',
#   'decideCnt': '28',
#   'examCnt': '562',
#   'seq': '24',
#   'stateDt': '20200213',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-13 17:09:07.07'},
#  {'clearCnt': '7',
#   'createDt': '2020-02-12 16:56:47.47',
#   'deathCnt': '0',
#   'decideCnt': '28',
#   'examCnt': '785',
#   'seq': '22',
#   'stateDt': '20200212',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-12 16:56:47.47'},
#  {'clearCnt': '4',
#   'createDt': '2020-02-11 17:09:25.25',
#   'deathCnt': '0',
#   'decideCnt': '28',
#   'examCnt': '762',
#   'seq': '20',
#   'stateDt': '20200211',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-11 17:09:25.25'},
#  {'clearCnt': '3',
#   'createDt': '2020-02-10 17:03:49.49',
#   'deathCnt': '0',
#   'decideCnt': '27',
#   'examCnt': '531',
#   'seq': '18',
#   'stateDt': '20200210',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-10 17:03:49.49'},
#  {'clearCnt': '3',
#   'createDt': '2020-02-09 16:59:21.21',
#   'deathCnt': '0',
#   'decideCnt': '27',
#   'examCnt': '888',
#   'seq': '16',
#   'stateDt': '20200209',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-09 16:59:21.21'},
#  {'clearCnt': '2',
#   'createDt': '2020-02-08 17:01:34.34',
#   'deathCnt': '0',
#   'decideCnt': '24',
#   'examCnt': '939',
#   'seq': '14',
#   'stateDt': '20200208',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-08 17:01:34.34'},
#  {'clearCnt': '2',
#   'createDt': '2020-02-07 17:20:45.45',
#   'deathCnt': '0',
#   'decideCnt': '24',
#   'examCnt': '327',
#   'seq': '9',
#   'stateDt': '20200207',
#   'stateTime': '16:00',
#   'updateDt': '2020-02-07 17:20:45.45'},
#  {'clearCnt': '1',
#   'createDt': '2020-02-06 9:09:49.49',
#   'deathCnt': '0',
#   'decideCnt': '23',
#   'examCnt': '169',
#   'seq': '7',
#   'stateDt': '20200206',
#   'stateTime': '09:00',
#   'updateDt': '2020-02-06 9:09:49.49'},
#  {'clearCnt': '1',
#   'createDt': '2020-02-05 20:05:40.40',
#   'deathCnt': '0',
#   'decideCnt': '19',
#   'examCnt': '40',
#   'seq': '6',
#   'stateDt': '20200205',
#   'stateTime': '19:00',
#   'updateDt': '2020-02-05 20:05:40.40'},
#  {'clearCnt': '0',
#   'createDt': '2020-02-03 21:26:59.59',
#   'deathCnt': '0',
#   'decideCnt': '0',
#   'examCnt': '0',
#   'seq': '4',
#   'stateDt': '20200204',
#   'stateTime': '00:00',
#   'updateDt': '2020-02-03 21:26:59.59'},
#  {'clearCnt': '0',
#   'createDt': '2020-02-03 14:41:17.17',
#   'deathCnt': '0',
#   'decideCnt': '15',
#   'examCnt': '0',
#   'seq': '3',
#   'stateDt': '20200203',
#   'stateTime': '09:00',
#   'updateDt': '2020-02-03 14:41:17.17'},
#  {'clearCnt': '2',
#   'createDt': '2020-02-03 12:22:49.49',
#   'deathCnt': '2',
#   'decideCnt': '2',
#   'examCnt': '2',
#   'seq': '2',
#   'stateDt': '20200202',
#   'stateTime': '09:00',
#   'updateDt': '2020-02-03 12:22:49.49'},
#  {'clearCnt': '1',
#   'createDt': '2020-01-31 17:47:33.33',
#   'deathCnt': '0',
#   'decideCnt': '0',
#   'examCnt': '1',
#   'seq': '1',
#   'stateDt': '20200201',
#   'stateTime': '18:00',
#   'updateDt': '2020-01-31 17:47:33.33'},
#  {'accDefRate': None,
#   'clearCnt': '1',
#   'createDt': '2020-01-31 17:47:33.33',
#   'deathCnt': '0',
#   'decideCnt': '0',
#   'examCnt': '1',
#   'seq': '1',
#   'stateDt': '20200101',
#   'stateTime': '18:00',
#   'updateDt': '2020-02-03 12:21:56.56'}]

# %%
item = response_content['response']['body']['items']['item']
df = pd.DataFrame(item)
df.to_csv('/content/drive/코로나(감염현황).csv', index = False)
