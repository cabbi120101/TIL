# %%
## 함수 선언부
def  isStackFull() :
    global SIZE, stack, top
    if (top >= SIZE-1) :
        return True
    else :
        return False

def push(data) :
    global SIZE, stack, top
    if (isStackFull()) :
        print('스택 꽉!')
        return
    top +=1
    stack[top] = data

def isStackEmpty() :
    global SIZE, stack, top
    

def pop() :
    global SIZE, stack, top
        
    return data

## 전역 변수부
SIZE = 5
stack = [None for _ in range(SIZE)]
top = -1

## 메인 코드부
# stack=['커피', '녹차', '꿀물', '콜라', '환타']
# top = 4
# print('스택 꽉?', isStackFull())
push('커피1');push('커피2');push('커피3');push('커피4')
push('커피5')
print(stack)
push('커피6')

retData = pop()
print('뽑기 -->', retData)
retData = pop()
print('뽑기 -->', retData)
retData = pop()
print('뽑기 -->', retData)
