# %%
katok = []

# %%
def add_data(friend):
    katok.append(None) #빈칸 추가
    kLen = len(katok)
    katok[kLen - 1] = friend

# %%
add_data('다현')
add_data('정현')
add_data('쯔위')
add_data('사나')
add_data('지효')

print(katok)
# Out:
# ['다현', '정현', '쯔위', '사나', '지효']
